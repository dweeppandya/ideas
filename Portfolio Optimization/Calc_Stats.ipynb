# %% [markdown]
# ## Imports

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
# %matplotlib inline

import datetime as dt

import time

import yfinance as yf

import os

import cufflinks as cf
import plotly.express as px
import plotly.graph_objects as go

from plotly.offline import download_plotlyjs, init_notebook_mode, plot, iplot
init_notebook_mode(connected=True)
cf.go_offline()

from plotly.subplots import make_subplots

from os import listdir
from os.path import isfile, join

import warnings
warnings.simplefilter("ignore")
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.8.3.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.8.3.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %% [markdown]
# ## Constants

# %%
PATH = "Data/"

# Start End date defaults
S_DATE = "2012-01-01"
E_DATE = "2023-01-01"
S_DATE_DT = pd.to_datetime(S_DATE)
E_DATE_DT = pd.to_datetime(E_DATE)

# %% [markdown]
# ## Get Dataframe from CSV

# %%
# Reads a dataframe from CSV file, changes index to date and returns it
def get_stock_df_from_csv(ticker):

    # Try to get the file and if it doesn't exist issue a warning
    try:
        df = pd.read_csv(PATH + ticker + '.csv', index_col=0)
    except FileNotFoundError:
        print("File doesn't exist")
    else:
        return df

# %% [markdown]
# ## Get all Stocks Downloaded in List

# %%
# Get all files and extract tickers from them
files = [x for x in listdir(PATH) if isfile(join(PATH, x))]
tickers = [os.path.splitext(x)[0] for x in files]
tickers.sort()
len(tickers)
# Out:
# 4105

# %% [markdown]
# ## Add Daily Returns

# %%
# Shift provides the value from the previous day
# NaN is displayed because there was no previous day price for the 1st calculation
def add_daily_return_to_df(df):
    df['daily_return'] = (df['Close']/df['Close'].shift(1)) - 1

    # Save data to a CSV file
    # df.to_csv(PATH + ticker + '.csv')
    return df

# %% [markdown]
# ## Add Cumulative Returns

# %%
def add_cum_return_to_df(df):
    df['cum_return'] = (1 + df['daily_return']).cumprod()
    # df.to_csv(PATH + ticker + '.csv')
    return df

# %% [markdown]
# ## Add Bollinger Bands
#
# An indicator of volatility.
#
# Bollinger Bands plot 2 lines using a moving average and the standard deviation defines how far apart the lines are. They also are used to define if prices are to high or low. When bands tighten it is believed a sharp price move in some direction. Prices tend to bounce off of the bands which provides potential market actions.
#
# A strong trend should be noted if the price moves outside the band. If prices go over the resistance line it is in overbought territory and if it breaks through support it is a sign of an oversold position.

# %%
# Here we will add a middle band (20 days), upper band (20 days + 1.96*std),
# and lower band (20 days - 1.96*std)
def add_bollinger_bands(df):
    df['middle_band'] = df['Close'].rolling(window=20).mean()
    df['upper_band'] = df['middle_band'] + 1.96*df['Close'].rolling(window=20).std()
    df['lower_band'] = df['middle_band'] - 1.96*df['Close'].rolling(window=20).std()
    # df.to_csv(PATH + ticker + '.csv')
    return df

# %% [markdown]
# ## Add Ichimoku Data to Dataframe
#
# The Ichimoku (One Look) is considered an all in one indicator. It provides information on momentum, support and resistance. It is made up of 5 lines. If you are a short term trader you create 1 minute or 6 hour. Long term traders focus on day or weekly data.
#
# - Conversion Line (Tenkan-sen) : Represents support, resistance and reversals. Used to measure short term trends.
# - Baseline (Kijun-sen) : Represents support, resistance and confirms trend changes. Allows you to evaluate the strength of medium term trends. Called the baseline because it lags the price.
# - Leading Span A (Senkou A) : Used to identify future areas of support and resistance
# - Leading Span B (Senkou B) : Other line used to identify future support and resistance
# - Lagging Span (Chikou) : Shows possible support and resistance. It is used to confirm signals obtained from other lines.
# - Cloud (Kumo) : Space between Span A and B. Represents the divergence in price evolution.
#
# Formulas
#
# - Lagging Span = Price shifted back 26 periods
# - Base Line = (Highest Value in period + Lowest value in period)/2 (26 Sessions)
# - Conversion Line = (Highest Value in period + Lowest value in period)/2 (9 Sessions)
# - Leading Span A = (Conversion Value + Base Value)/2 (26 Sessions)
# - Leading Span B = (Conversion Value + Base Value)/2 (52 Sessions)

# %%
def add_Ichimoku(df):
    # Conversion
    hi_val = df['High'].rolling(window=9).max()
    low_val = df['Low'].rolling(window=9).min()
    df['Conversion'] = (hi_val + low_val)/2

    # Baseline
    hi_val2 = df['High'].rolling(window=26).max()
    low_val2 = df['Low'].rolling(window=26).min()
    df['Baseline'] = (hi_val2 + low_val2)/2

    # Spans
    df['SpanA'] = ((df['Conversion'] + df['Baseline'])/2).shift(26)
    hi_val3 = df['High'].rolling(window=52).max()
    low_val3 = df['Low'].rolling(window=52).min()
    df['SpanB'] = ((hi_val3 + low_val3)/2).shift(26)
    df['Lagging'] = df['Close'].shift(-26)

    return df

# %% [markdown]
# ## Add Daily, Cumulative Bollinger Bands & Ichimoku to Dataframes

# %%
for x in tickers:
    try:
        print("Working on: ", x)
        new_df = get_stock_df_from_csv(x)
        new_df = add_daily_return_to_df(new_df)
        new_df = add_cum_return_to_df(new_df)
        new_df = add_bollinger_bands(new_df)
        new_df = add_Ichimoku(new_df)
        new_df.to_csv(PATH + x + '.csv')
    except Exception as ex:
        print(ex)
# Out:
# Working on:  08ABB_BO
# Working on:  08ADD_BO
# Working on:  08ADR_BO
# Working on:  08AGG_BO
# Working on:  08AMD_BO
# Working on:  08AMR_BO
# Working on:  08AQD_BO
# Working on:  08AQR_BO
# Working on:  08BPB_BO
# Working on:  08DPD_BO
# Working on:  08DPR_BO
# Working on:  08GPG_BO
# Working on:  08MPD_BO
# Working on:  08MPR_BO
# Working on:  08QPD_BO
# Working on:  08QPR_BO
# Working on:  11ADD_BO
# Working on:  11ADR_BO
# Working on:  11AGG_BO
# Working on:  11AMD_BO
# Working on:  11AMR_BO
# Working on:  11AQD_BO
# Working on:  11AQR_BO
# Working on:  11DPD_BO
# Working on:  11DPR_BO
# Working on:  11GPG_BO
# Working on:  11MPD_BO
# Working on:  11MPR_BO
# Working on:  11QPD_BO
# Working on:  11QPR_BO
# Working on:  1STCUS_BO
# Working on:  20MICRONS_BO
# Working on:  21STCENMGM_BO
# Working on:  3MINDIA_BO
# Working on:  3PLAND_BO
# Working on:  4THGEN_BO
# Working on:  5PAISA_BO
# Working on:  63MOONS_BO
# Working on:  7NR_BO
# Working on:  7SEASL_BO
# Working on:  7TEC_BO
# Working on:  A2ZINFRA_BO
# Working on:  AADIIND_BO
# Working on:  AAIL_BO
# Working on:  AAL_BO
# Working on:  AANANDALAK_BO
# Working on:  AANCHALISP_BO
# Working on:  AAPLUSTRAD_BO
# Working on:  AARCOM_BO
# Working on:  AARNAV_BO
# Working on:  AARSHYAM_BO
# Working on:  AARTECH_BO
# Working on:  AARTIDRUGS_BO
# Working on:  AARTIIND_BO
# Working on:  AARTISURF_BO
# Working on:  AARVEEDEN_BO
# Working on:  AARVINFRA_BO
# Working on:  AASHKA_BO
# Working on:  AAVAS_BO
# Working on:  AAYUSH_BO
# Working on:  ABANSENT_BO
# Working on:  ABAN_BO
# Working on:  ABBOTINDIA_BO
# Working on:  ABB_BO
# Working on:  ABCAPITAL_BO
# Working on:  ABCINDQ_BO
# Working on:  ABFRL_BO
# Working on:  ABHICAP_BO
# Working on:  ABHIFIN_BO
# Working on:  ABHIINFRA_BO
# Working on:  ABHIJIT_BO
# Working on:  ABIRAFN_BO
# Working on:  ABMKNO_BO
# Working on:  ABSLAMC_BO
# Working on:  ABSLBANETF_BO
# Working on:  ABSLNN50ET_BO
# Working on:  ABVL_BO
# Working on:  ACCELYA_BO
# Working on:  ACCEL_BO
# Working on:  ACC_BO
# Working on:  ACEMEN_BO
# Working on:  ACESOFT_BO
# Working on:  ACEWIN_BO
# Working on:  ACE_BO
# Working on:  ACFL_BO
# Working on:  ACFSL_BO
# Working on:  ACGL_BO
# Working on:  ACIIN_BO
# Working on:  ACKNIT_BO
# Working on:  ACME_BO
# Working on:  ACML_BO
# Working on:  ACROW_BO
# Working on:  ACRYSIL_BO
# Working on:  ACTIVE_BO
# Working on:  ADANIENT_BO
# Working on:  ADANIGREEN_BO
# Working on:  ADANIPORTS_BO
# Working on:  ADANIPOWER_BO
# Working on:  ADANITRANS_BO
# Working on:  ADARSHPL_BO
# Working on:  ADARSH_BO
# Working on:  ADCINDIA_BO
# Working on:  ADCON_BO
# Working on:  ADDIND_BO
# Working on:  ADESHWAR_BO
# Working on:  ADFFOODS_BO
# Working on:  ADHARSHILA_BO
# Working on:  ADHIRAJ_BO
# Working on:  ADIEXRE_BO
# Working on:  ADINATH_BO
# Working on:  ADISHAKTI_BO
# Working on:  ADITYASP_BO
# Working on:  ADITYA_BO
# Working on:  ADL_BO
# Working on:  ADMANUM_BO
# Working on:  ADORFO_BO
# Working on:  ADORMUL_BO
# Working on:  ADORWELD_BO
# Working on:  ADROITINFO_BO
# Working on:  ADSL_BO
# Working on:  ADVAIT_BO
# Working on:  ADVANIHOTR_BO
# Working on:  ADVENZYMES_BO
# Working on:  ADVIKCA_BO
# Working on:  ADVITIYA_BO
# Working on:  ADVLIFE_BO
# Working on:  ADVPETR-B_BO
# Working on:  AEGISLOG_BO
# Working on:  AEL_BO
# Working on:  AFEL_BO
# Working on:  AFFLE_BO
# Working on:  AFFORDABLE_BO
# Working on:  AGARIND_BO
# Working on:  AGCNET_BO
# Working on:  AGIIL_BO
# Working on:  AGIOPAPER_BO
# Working on:  AGOL_BO
# Working on:  AGRIMONY_BO
# Working on:  AGRITECH_BO
# Working on:  AHLEAST_BO
# Working on:  AHLUCONT_BO
# Working on:  AHLWEST_BO
# Working on:  AHMDSTE_BO
# Working on:  AIAENG_BO
# Working on:  AICHAMP_BO
# Working on:  AIHL_BO
# Working on:  AIIL_BO
# Working on:  AIMCOPEST_BO
# Working on:  AIML_BO
# Working on:  AINFRA_BO
# Working on:  AIRTEL-RE_BO
# Working on:  AISHWARYA_BO
# Working on:  AJANTPHARM_BO
# Working on:  AJANTSOY_BO
# Working on:  AJCON_BO
# Working on:  AJEL_BO
# Working on:  AJIL_BO
# Working on:  AJMERA_BO
# Working on:  AJRINFRA_BO
# Working on:  AJWAFUN_BO
# Working on:  AKASHDEEP_BO
# Working on:  AKCAPIT_BO
# Working on:  AKI_BO
# Working on:  AKM_BO
# Working on:  AKSCHEM_BO
# Working on:  AKSHAR_BO
# Working on:  AKSHOPTFBR_BO
# Working on:  AKSPINTEX_BO
# Working on:  AKZOINDIA_BO
# Working on:  ALAN SCOTT_BO
# Working on:  ALANKIT_BO
# Working on:  ALBERTDA_BO
# Working on:  ALCHCORP_BO
# Working on:  ALEMBICLTD_BO
# Working on:  ALEXANDER_BO
# Working on:  ALFAICA_BO
# Working on:  ALFATRAN_BO
# Working on:  ALFAVIO_BO
# Working on:  ALFL_BO
# Working on:  ALFREDHE_BO
# Working on:  ALICON_BO
# Working on:  ALKALI_BO
# Working on:  ALKA_BO
# Working on:  ALKEM_BO
# Working on:  ALKYLAMINE_BO
# Working on:  ALLCARGO_BO
# Working on:  ALLSEC_BO
# Working on:  ALMONDZ_BO
# Working on:  ALNATRD_BO
# Working on:  ALOKTEXT_BO
# Working on:  ALPA_BO
# Working on:  ALPHAGEO_BO
# Working on:  ALPINEHOU_BO
# Working on:  ALPSINDUS_BO
# Working on:  ALSL_BO
# Working on:  ALSTONE_BO
# Working on:  ALUFLUOR_BO
# Working on:  AMALGAM_BO
# Working on:  AMAL_BO
# Working on:  AMANITRA_BO
# Working on:  AMARAJABAT_BO
# Working on:  AMARDEE_BO
# Working on:  AMARJOTHI_BO
# Working on:  AMARNATH_BO
# Working on:  AMBALALSA_BO
# Working on:  AMBARPIL_BO
# Working on:  AMBER_BO
# Working on:  AMBICAAGAR_BO
# Working on:  AMBIKCO_BO
# Working on:  AMBITION_BO
# Working on:  AMBUJACEM_BO
# Working on:  AMCOIND_BO
# Working on:  AMDIND_BO
# Working on:  AMFL_BO
# Working on:  AMFORG_BO
# Working on:  AMINTAN_BO
# Working on:  AMIORG_BO
# Working on:  AMITINT_BO
# Working on:  AMJLAND_BO
# Working on:  AML_BO
# Working on:  AMNPLST_BO
# Working on:  AMRAAGRI_BO
# Working on:  AMRAFIN_BO
# Working on:  AMRAPLIN_BO
# Working on:  AMRITCORP_BO
# Working on:  AMRUTANJAN_BO
# Working on:  AMS_BO
# Working on:  AMTL_BO
# Working on:  ANANDPROJ_BO
# Working on:  ANANTRAJ_BO
# Working on:  ANDHRACEMT_BO
# Working on:  ANDHRAPAP_BO
# Working on:  ANDHRAPET_BO
# Working on:  ANDHRSUGAR_BO
# Working on:  ANDREWYU_BO
# Working on:  ANERI_BO
# Working on:  ANGELBRKG_BO
# Working on:  ANGEL_BO
# Working on:  ANG_BO
# Working on:  ANIKINDS_BO
# Working on:  ANJANIFIN_BO
# Working on:  ANJANIFOODS_BO
# Working on:  ANJANI_BO
# Working on:  ANKIN_BO
# Working on:  ANKITMETAL_BO
# Working on:  ANMOL_BO
# Working on:  ANNAINFRA_BO
# Working on:  ANSALAPI_BO
# Working on:  ANSALBU_BO
# Working on:  ANSALHSG_BO
# Working on:  ANSHNCO_BO
# Working on:  ANSINDUS_BO
# Working on:  ANTARIKSH_BO
# Working on:  ANUBHAV_BO
# Working on:  ANUHPHR_BO
# Working on:  ANUPAM_BO
# Working on:  ANUP_BO
# Working on:  ANURAS_BO
# Working on:  ANUROOP_BO
# Working on:  APARINDS_BO
# Working on:  APCL_BO
# Working on:  APCOTEXIND_BO
# Working on:  APEX_BO
# Working on:  APIL_BO
# Working on:  APIS_BO
# Working on:  APLAB_BO
# Working on:  APLAPOLLO_BO
# Working on:  APLLTD_BO
# Working on:  APMFINVEST_BO
# Working on:  APMIN_BO
# Working on:  APOLLOFI_BO
# Working on:  APOLLOHOSP_BO
# Working on:  APOLLOPIPES_BO
# Working on:  APOLLOTRI_BO
# Working on:  APOLLOTYRE_BO
# Working on:  APOLLO_BO
# Working on:  APOORVA_BO
# Working on:  APTECHT_BO
# Working on:  APTUS_BO
# Working on:  ARAMBHAN_BO
# Working on:  ARAVALIS_BO
# Working on:  ARCEEIN_BO
# Working on:  ARCFIN_BO
# Working on:  ARCHIDPLY_BO
# Working on:  ARCHIES_BO
# Working on:  ARCHITORG_BO
# Working on:  ARENTERP_BO
# Working on:  AREXMIS_BO
# Working on:  AREYDRG_BO
# Working on:  ARFIN_BO
# Working on:  ARHNTTO_BO
# Working on:  ARIES_BO
# Working on:  ARIHANT_BO
# Working on:  ARIHCAPM_BO
# Working on:  ARISE_BO
# Working on:  ARISINT_BO
# Working on:  ARL_BO
# Working on:  ARMANFIN_BO
# Working on:  ARMAN_BO
# Working on:  ARNOLD_BO
# Working on:  AROGRANITE_BO
# Working on:  AROMAENT_BO
# Working on:  ARROWGREEN_BO
# Working on:  ARSHIYA_BO
# Working on:  ARSSINFRA_BO
# Working on:  ARTEFACT_BO
# Working on:  ARTEMISELC_BO
# Working on:  ARTEMISMED_BO
# Working on:  ARTSONEN_BO
# Working on:  ARUNAHTEL_BO
# Working on:  ARUNIS_BO
# Working on:  ARVINDFASN_BO
# Working on:  ARVIND_BO
# Working on:  ARVSMART_BO
# Working on:  ARYACAPM_BO
# Working on:  ARYAMAN_BO
# Working on:  ARYAN_BO
# Working on:  ARYAVAN_BO
# Working on:  ASAHIINDIA_BO
# Working on:  ASAHIIND_BO
# Working on:  ASAHISONG_BO
# Working on:  ASALCBR_BO
# Working on:  ASAL_BO
# Working on:  ASHAI_BO
# Working on:  ASHAPURMIN_BO
# Working on:  ASHCAP_BO
# Working on:  ASHIANA_BO
# Working on:  ASHIKACR_BO
# Working on:  ASHIMASYN_BO
# Working on:  ASHISHPO_BO
# Working on:  ASHIS_BO
# Working on:  ASHNI_BO
# Working on:  ASHNOOR_BO
# Working on:  ASHOKALC_BO
# Working on:  ASHOKA_BO
# Working on:  ASHOKLEY_BO
# Working on:  ASHOKRE_BO
# Working on:  ASHRAM_BO
# Working on:  ASHSI_BO
# Working on:  ASHUTPM_BO
# Working on:  ASIACAP_BO
# Working on:  ASIANENE_BO
# Working on:  ASIANHOTNR_BO
# Working on:  ASIANPAINT_BO
# Working on:  ASIANTILES_BO
# Working on:  ASIANTNE_BO
# Working on:  ASIAPAK_BO
# Working on:  ASIIL_BO
# Working on:  ASINPET_BO
# Working on:  ASITCFIN_BO
# Working on:  ASL_BO
# Working on:  ASMTEC_BO
# Working on:  ASPIRA_BO
# Working on:  ASRL_BO
# Working on:  ASSAMENT_BO
# Working on:  ASTAR_BO
# Working on:  ASTEC_BO
# Working on:  ASTERDM_BO
# Working on:  ASTRAL_BO
# Working on:  ASTRAMICRO_BO
# Working on:  ASTRAZEN_BO
# Working on:  ASTRON_BO
# Working on:  ASUTENT_BO
# Working on:  ASWTR_BO
# Working on:  ASYAINFO_BO
# Working on:  ASYL_BO
# Working on:  ATAM_BO
# Working on:  ATFL_BO
# Working on:  ATGL_BO
# Working on:  ATHARVENT_BO
# Working on:  ATHCON_BO
# Working on:  ATHENAGLO_BO
# Working on:  ATISHAY_BO
# Working on:  ATLANTA_BO
# Working on:  ATULAUTO_BO
# Working on:  ATUL_BO
# Working on:  ATVPR_BO
# Working on:  AUBANK_BO
# Working on:  AURIONPRO_BO
# Working on:  AUROLAB_BO
# Working on:  AUROPHARMA_BO
# Working on:  AUSOMENT_BO
# Working on:  AUSTENG_BO
# Working on:  AUTOAXLES_BO
# Working on:  AUTOIND_BO
# Working on:  AUTOINT_BO
# Working on:  AUTOPINS_BO
# Working on:  AVADHSUGAR_BO
# Working on:  AVAILFC_BO
# Working on:  AVANTEL_BO
# Working on:  AVANTI_BO
# Working on:  AVIVA_BO
# Working on:  AVI_BO
# Working on:  AVL_BO
# Working on:  AVONMORE_BO
# Working on:  AVTNPL_BO
# Working on:  AWHCL_BO
# Working on:  AXELPOLY_BO
# Working on:  AXISBANK_BO
# Working on:  AXISCADES_BO
# Working on:  AXISCBD1D_BO
# Working on:  AXISCBDGG_BO
# Working on:  AXISCBDPD_BO
# Working on:  AXISCBGPG_BO
# Working on:  AXISCCDGG_BO
# Working on:  AXISCCDID_BO
# Working on:  AXISCCDPD_BO
# Working on:  AXISCCGPG_BO
# Working on:  AXISCETF_BO
# Working on:  AXISHETF_BO
# Working on:  AXISTECETF_BO
# Working on:  AXITA_BO
# Working on:  AXTEL_BO
# Working on:  AYMSYNTEX_BO
# Working on:  AYOME_BO
# Working on:  B2BSOFT_BO
# Working on:  BABA_BO
# Working on:  BACPHAR_BO
# Working on:  BAFNAPHARM_BO
# Working on:  BAGFILMS_BO
# Working on:  BAJAJ-AUTO_BO
# Working on:  BAJAJCON_BO
# Working on:  BAJAJELEC_BO
# Working on:  BAJAJFINSV_BO
# Working on:  BAJAJHCARE_BO
# Working on:  BAJAJHIND_BO
# Working on:  BAJAJHLDNG_BO
# Working on:  BAJAJST_BO
# Working on:  BAJFINANCE_BO
# Working on:  BAJGLOB_BO
# Working on:  BALAJITELE_BO
# Working on:  BALAMINES_BO
# Working on:  BALFC_BO
# Working on:  BALGOPAL_BO
# Working on:  BALKRISHNA_BO
# Working on:  BALKRISIND_BO
# Working on:  BALLARPUR_BO
# Working on:  BALMLAWRIE_BO
# Working on:  BALPHARMA_BO
# Working on:  BALRAMCHIN*_BO
# Working on:  BALTE_BO
# Working on:  BALUFORGE_BO
# Working on:  BAMBINO_BO
# Working on:  BAMPSL_BO
# Working on:  BANARBEADS_BO
# Working on:  BANARISUG_BO
# Working on:  BANASFN_BO
# Working on:  BANCOINDIA_BO
# Working on:  BANDHANBNK_BO
# Working on:  BANG_BO
# Working on:  BANKBARODA_BO
# Working on:  BANKBEES_BO
# Working on:  BANKINDIA_BO
# Working on:  BANSTEA_BO
# Working on:  BANSWRAS_BO
# Working on:  BAPACK_BO
# Working on:  BARBEQUE_BO
# Working on:  BAROEXT_BO
# Working on:  BARTRONICS_BO
# Working on:  BASANTGL_BO
# Working on:  BASF_BO
# Working on:  BASML_BO
# Working on:  BATAINDIA_BO
# Working on:  BATLIBOI_BO
# Working on:  BAYERCROP_BO
# Working on:  BAZELINTER_BO
# Working on:  BBL_BO
# Working on:  BBTC_BO
# Working on:  BCCFUBA_BO
# Working on:  BCG_BO
# Working on:  BCLENTERPR_BO
# Working on:  BCLIL_BO
# Working on:  BCPL_BO
# Working on:  BCP_BO
# Working on:  BDH_BO
# Working on:  BDL_BO
# Working on:  BEARDSELL_BO
# Working on:  BECTORFOOD_BO
# Working on:  BEDMUTHA_BO
# Working on:  BEEKAY_BO
# Working on:  BEEYU_BO
# Working on:  BELLACASA_BO
# Working on:  BEL_BO
# Working on:  BEMHY_BO
# Working on:  BEML_BO
# Working on:  BENARAS_BO
# Working on:  BENARA_BO
# Working on:  BENGALASM_BO
# Working on:  BENGALS_BO
# Working on:  BENGALT_BO
# Working on:  BENTCOM_BO
# Working on:  BEPL_BO
# Working on:  BERGEPAINT_BO
# Working on:  BERLDRG_BO
# Working on:  BERVINL_BO
# Working on:  BERYLSE_BO
# Working on:  BESTAGRO_BO
# Working on:  BESTEAST_BO
# Working on:  BETXIND_BO
# Working on:  BFFL_BO
# Working on:  BFINVEST_BO
# Working on:  BFLAFL_BO
# Working on:  BFUTILITIE_BO
# Working on:  BGJL_BO
# Working on:  BGRENERGY_BO
# Working on:  BGWTATO_BO
# Working on:  BHAGCHEM_BO
# Working on:  BHAGIL_BO
# Working on:  BHAGWOX_BO
# Working on:  BHAGYAPROP_BO
# Working on:  BHAGYNAGAR_BO
# Working on:  BHANDERI_BO
# Working on:  BHANDHOS_BO
# Working on:  BHARATAGRI_BO
# Working on:  BHARATFORG_BO
# Working on:  BHARATGEAR_BO
# Working on:  BHARATRAS_BO
# Working on:  BHARATSE_BO
# Working on:  BHARATWIRE_BO
# Working on:  BHARAT_BO
# Working on:  BHARTIARTL_BO
# Working on:  BHARTIA_BO
# Working on:  BHASKAGR_BO
# Working on:  BHATIA_BO
# Working on:  BHEL_BO
# Working on:  BHILSPIN_BO
# Working on:  BIBCL_BO
# Working on:  BIGBLOC_BO
# Working on:  BIHSPONG_BO
# Working on:  BIJHANS_BO
# Working on:  BILLWIN_BO
# Working on:  BIL_BO
# Working on:  BIMETAL_BO
# Working on:  BINDALAGRO_BO
# Working on:  BINDALEXPO_BO
# Working on:  BINNYMILLS_BO
# Working on:  BINNY_BO
# Working on:  BIOCON_BO
# Working on:  BIOFILCHEM_BO
# Working on:  BIOGEN_BO
# Working on:  BIRLACABLE_BO
# Working on:  BIRLACORPN_BO
# Working on:  BIRLAMONEY_BO
# Working on:  BIRLAPREC_BO
# Working on:  BIRLATYRES_BO
# Working on:  BITL_BO
# Working on:  BI_BO
# Working on:  BKMINDST_BO
# Working on:  BKV_BO
# Working on:  BLACKROSE_BO
# Working on:  BLBLIMITED_BO
# Working on:  BLFL_BO
# Working on:  BLIL_BO
# Working on:  BLISSGVS_BO
# Working on:  BLKASHYAP_BO
# Working on:  BLOOM_BO
# Working on:  BLS_BO
# Working on:  BLUECHIPT_BO
# Working on:  BLUECHIP_BO
# Working on:  BLUECLOUDS_BO
# Working on:  BLUECOAST_BO
# Working on:  BLUEDART_BO
# Working on:  BLUESTARCO_BO
# Working on:  BMAL_BO
# Working on:  BMW_BO
# Working on:  BNALTD_BO
# Working on:  BNKCAP_BO
# Working on:  BNL_BO
# Working on:  BNRSEC_BO
# Working on:  BNRUDY_BO
# Working on:  BODALCHEM_BO
# Working on:  BODHTREE_BO
# Working on:  BOMBCYC_BO
# Working on:  BOMBPOT_BO
# Working on:  BOMDYEING_BO
# Working on:  BOMOXY-B1_BO
# Working on:  BONLON_BO
# Working on:  BOROLTD_BO
# Working on:  BORORENEW_BO
# Working on:  BOSCHLTD_BO
# Working on:  BPCAP_BO
# Working on:  BPCL_BO
# Working on:  BPLPHARMA_BO
# Working on:  BPL_BO
# Working on:  BPTEX_BO
# Working on:  BRADYM_BO
# Working on:  BRAHMINFRA_BO
# Working on:  BRANDREAL_BO
# Working on:  BRAWN_BO
# Working on:  BRFL_BO
# Working on:  BRIDGESE_BO
# Working on:  BRIGADE_BO
# Working on:  BRIGHTBR_BO
# Working on:  BRIJLEAS_BO
# Working on:  BRIPORT_BO
# Working on:  BRITANNIA_BO
# Working on:  BRNL_BO
# Working on:  BROOKS_BO
# Working on:  BRPL_BO
# Working on:  BSELINFRA_BO
# Working on:  BSLSENETFG_BO
# Working on:  BSL_BO
# Working on:  BSOFT_BO
# Working on:  BTTL_BO
# Working on:  BUDGE BUDGE_BO
# Working on:  BURGERKING_BO
# Working on:  BURNPUR_BO
# Working on:  BUTTERFLY_BO
# Working on:  BVCL_BO
# Working on:  BVL_BO
# Working on:  CADILAHC_BO
# Working on:  CALCOM_BO
# Working on:  CALSOFT_BO
# Working on:  CAMEXLTD_BO
# Working on:  CAMLINFINE_BO
# Working on:  CAMS_BO
# Working on:  CANBK_BO
# Working on:  CANDC_BO
# Working on:  CANFINHOME_BO
# Working on:  CANOPYFIN_BO
# Working on:  CANTABIL_BO
# Working on:  CAPACITE_BO
# Working on:  CAPFIN_BO
# Working on:  CAPITALT_BO
# Working on:  CAPPIPES_BO
# Working on:  CAPPL_BO
# Working on:  CAPRICORN_BO
# Working on:  CAPRIHANS_BO
# Working on:  CAPRO_BO
# Working on:  CARBORUNIV_BO
# Working on:  CAREERP_BO
# Working on:  CARERATING_BO
# Working on:  CARNATIN_BO
# Working on:  CARTRADE_BO
# Working on:  CASTROLIND_BO
# Working on:  CATVISION_BO
# Working on:  CBPL_BO
# Working on:  CCCL_BO
# Working on:  CCFCL_BO
# Working on:  CCHHL_BO
# Working on:  CCLINTER_BO
# Working on:  CCL_BO
# Working on:  CDG_BO
# Working on:  CEATLTD_BO
# Working on:  CEBBCO_BO
# Working on:  CEEJAY_BO
# Working on:  CEENIK_BO
# Working on:  CEETAIN_BO
# Working on:  CEINSYSTECH_BO
# Working on:  CELEBRITY_BO
# Working on:  CELLA_BO
# Working on:  CENLUB_BO
# Working on:  CENTENKA_BO
# Working on:  CENTERAC_BO
# Working on:  CENTEXT_BO
# Working on:  CENTRALBK_BO
# Working on:  CENTRUM_BO
# Working on:  CENTUM_BO
# Working on:  CENTURYPLY_BO
# Working on:  CENTURYTEX_BO
# Working on:  CERA_BO
# Working on:  CEREBRAINT_BO
# Working on:  CESC_BO
# Working on:  CESL_BO
# Working on:  CFEL_BO
# Working on:  CFL_BO
# Working on:  CGCL_BO
# Working on:  CGPOWER_BO
# Working on:  CGVAK_BO
# Working on:  CHADPAP_BO
# Working on:  CHALET_BO
# Working on:  CHAMAK_BO
# Working on:  CHAMANSEQ_BO
# Working on:  CHAMBLFERT_BO
# Working on:  CHANDNIMACH_BO
# Working on:  CHANDNI_BO
# Working on:  CHANDRAP_BO
# Working on:  CHANDRIMA_BO
# Working on:  CHARMS_BO
# Working on:  CHCL_BO
# Working on:  CHDCHEM_BO
# Working on:  CHEMBOND_BO
# Working on:  CHEMCON_BO
# Working on:  CHEMCRUX_BO
# Working on:  CHEMFABALKA_BO
# Working on:  CHEMIESYNT_BO
# Working on:  CHEMOPH_BO
# Working on:  CHEMPLASTS_BO
# Working on:  CHEMTECH_BO
# Working on:  CHENFERRO_BO
# Working on:  CHENNPETRO_BO
# Working on:  CHEVIOT_BO
# Working on:  CHLLTD_BO
# Working on:  CHLOGIST_BO
# Working on:  CHMBBRW_BO
# Working on:  CHOICEIN_BO
# Working on:  CHOKSILA_BO
# Working on:  CHOKSI_BO
# Working on:  CHOLAFIN_BO
# Working on:  CHOLAHLDNG_BO
# Working on:  CHORDIA_BO
# Working on:  CHOTHANI_BO
# Working on:  CHOWGULSTM_BO
# Working on:  CHRTEDCA_BO
# Working on:  CIANAGRO_BO
# Working on:  CIFL_BO
# Working on:  CIGNITI_BO
# Working on:  CILSEC_BO
# Working on:  CIL_BO
# Working on:  CINDHO_BO
# Working on:  CINDRELL_BO
# Working on:  CINELINE_BO
# Working on:  CINERAD_BO
# Working on:  CINEVISTA_BO
# Working on:  CIPLA_BO
# Working on:  CISTRO_BO
# Working on:  CITADEL_BO
# Working on:  CITIPOR_BO
# Working on:  CITL_BO
# Working on:  CITYMAN_BO
# Working on:  CITYONLINE_BO
# Working on:  CITYON_BO
# Working on:  CJGEL_BO
# Working on:  CLASELE_BO
# Working on:  CLEAN_BO
# Working on:  CLEDUCATE_BO
# Working on:  CLFL_BO
# Working on:  CLIOINFO_BO
# Working on:  CLNINDIA_BO
# Working on:  CMBL_BO
# Working on:  CMI_BO
# Working on:  CMMHOSP_BO
# Working on:  CNIRESLTD_BO
# Working on:  CNOVAPETRO_BO
# Working on:  COALINDIA_BO
# Working on:  COARO_BO
# Working on:  COASTCORP_BO
# Working on:  COCHINM_BO
# Working on:  COCHINSHIP_BO
# Working on:  COCHMAL_BO
# Working on:  COCKERILL_BO
# Working on:  COFFEEDAY_BO
# Working on:  COFORGE_BO
# Working on:  COLINZ_BO
# Working on:  COLORCHIPS_BO
# Working on:  COLPAL_BO
# Working on:  COMCL_BO
# Working on:  COMFINCAP_BO
# Working on:  COMFINTE_BO
# Working on:  COMPEAU_BO
# Working on:  COMPUAGE_BO
# Working on:  COMPUSOFT_BO
# Working on:  COMSYN_BO
# Working on:  CONART_BO
# Working on:  CONCORD_BO
# Working on:  CONCOR_BO
# Working on:  CONFINT_BO
# Working on:  CONFIPET_BO
# Working on:  CONTICON_BO
# Working on:  CONTILI_BO
# Working on:  CONTPTR_BO
# Working on:  CONTROLPR_BO
# Working on:  CORAGRO_BO
# Working on:  CORALAB_BO
# Working on:  CORALFINAC_BO
# Working on:  CORDSCABLE_BO
# Working on:  CORNE_BO
# Working on:  COROENGG_BO
# Working on:  COROMANDEL_BO
# Working on:  CORPOCO_BO
# Working on:  COSCO_BO
# Working on:  COSMOFE_BO
# Working on:  COSMOFILMS_BO
# Working on:  COSPOWER_BO
# Working on:  COSYN_BO
# Working on:  COUNCODOS_BO
# Working on:  COX&KINGS_BO
# Working on:  CPL_BO
# Working on:  CPML_BO
# Working on:  CPSEETF_BO
# Working on:  CRAFTSMAN_BO
# Working on:  CRANEINFRA_BO
# Working on:  CRANESSOFT_BO
# Working on:  CRANEX_BO
# Working on:  CRAVATEX_BO
# Working on:  CREATIVEYE_BO
# Working on:  CREATIVE_BO
# Working on:  CREDITACC_BO
# Working on:  CRESSAN_BO
# Working on:  CREST_BO
# Working on:  CRIMSON_BO
# Working on:  CRISIL_BO
# Working on:  CROISSANCE_BO
# Working on:  CROMPTON_BO
# Working on:  CROWNTOURS_BO
# Working on:  CRSTCHM_BO
# Working on:  CSBBANK_BO
# Working on:  CSLFINANCE_BO
# Working on:  CSL_BO
# Working on:  CSURGSU_BO
# Working on:  CTCL_BO
# Working on:  CTE_BO
# Working on:  CTL_BO
# Working on:  CUBEXTUB_BO
# Working on:  CUBIFIN_BO
# Working on:  CUB_BO
# Working on:  CUMMINSIND_BO
# Working on:  CUPID_BO
# Working on:  CYBELEIND_BO
# Working on:  CYBERMEDIA_BO
# Working on:  CYBERTECH_BO
# Working on:  CYIENT_BO
# Working on:  DAAWAT_BO
# Working on:  DABUR_BO
# Working on:  DAICHI_BO
# Working on:  DAIKAFFI_BO
# Working on:  DALBHARAT_BO
# Working on:  DALMIASUG_BO
# Working on:  DAL_BO
# Working on:  DAMOINDUS_BO
# Working on:  DANLAW_BO
# Working on:  DANUBE_BO
# Working on:  DARJEELING_BO
# Working on:  DARSHANORNA_BO
# Working on:  DATAMATICS_BO
# Working on:  DATIWARE_BO
# Working on:  DAULAT_BO
# Working on:  DAVANGERE_BO
# Working on:  DBCORP_BO
# Working on:  DBL_BO
# Working on:  DBREALTY_BO
# Working on:  DBSTOCKBRO_BO
# Working on:  DCAL_BO
# Working on:  DCBBANK_BO
# Working on:  DCL_BO
# Working on:  DCMFINSERV_BO
# Working on:  DCMNVL_BO
# Working on:  DCMSHRIRAM_BO
# Working on:  DCMSRMIND_BO
# Working on:  DCM_BO
# Working on:  DCW_BO
# Working on:  DDIL_BO
# Working on:  DECANBRG_BO
# Working on:  DECCANCE_BO
# Working on:  DECCAN_BO
# Working on:  DECIPHER_BO
# Working on:  DECNGOLD_BO
# Working on:  DECOMIC_BO
# Working on:  DECPO_BO
# Working on:  DEEPAKFERT_BO
# Working on:  DEEPAKNI_BO
# Working on:  DEEPAKSP_BO
# Working on:  DEEPENR_BO
# Working on:  DEEPIND_BO
# Working on:  DEEP_BO
# Working on:  DELPHIFX_BO
# Working on:  DELTACORP_BO
# Working on:  DELTAMAGNT_BO
# Working on:  DELTA_BO
# Working on:  DEL_BO
# Working on:  DENISCHEM_BO
# Working on:  DENORA_BO
# Working on:  DEN_BO
# Working on:  DESHRAK_BO
# Working on:  DEVHARI_BO
# Working on:  DEVINE_BO
# Working on:  DEVITRD_BO
# Working on:  DEVKI_BO
# Working on:  DEVYANI_BO
# Working on:  DFM_BO
# Working on:  DGCONTENT_BO
# Working on:  DGL_BO
# Working on:  DHABRIYA_BO
# Working on:  DHAMPURE_BO
# Working on:  DHAMPURSUG_BO
# Working on:  DHANBANK_BO
# Working on:  DHANCOT_BO
# Working on:  DHANFAB_BO
# Working on:  DHANI_BO
# Working on:  DHANROTO_BO
# Working on:  DHANUKA_BO
# Working on:  DHANVARSHA_BO
# Working on:  DHARAMSI_BO
# Working on:  DHARFIN_BO
# Working on:  DHARSUGAR_BO
# Working on:  DHENUBUILD_BO
# Working on:  DHINDIA_BO
# Working on:  DHOOTIN_BO
# Working on:  DHPIND_BO
# Working on:  DHRUVCA_BO
# Working on:  DHRUVES_BO
# Working on:  DHRUV_BO
# Working on:  DHUNINV_BO
# Working on:  DHUNTEAIND_BO
# Working on:  DIAMINESQ_BO
# Working on:  DIAMONDYD_BO
# Working on:  DIANATEA_BO
# Working on:  DICIND_BO
# Working on:  DIGISPICE_BO
# Working on:  DIKSAT_BO
# Working on:  DILIGENT_BO
# Working on:  DISAQ_BO
# Working on:  DISHTV_BO
# Working on:  DITCO_BO
# Working on:  DIVISLAB_BO
# Working on:  DIVSHKT_BO
# Working on:  DIXON_BO
# Working on:  DJML_BO
# Working on:  DLCL_BO
# Working on:  DLF_BO
# Working on:  DLINKINDIA_BO
# Working on:  DLTNCBL_BO
# Working on:  DMART_BO
# Working on:  DML_BO
# Working on:  DNAMEDIA_BO
# Working on:  DODLA_BO
# Working on:  DOLAT_BO
# Working on:  DOLFIN_BO
# Working on:  DOLLAR_BO
# Working on:  DOLPHMED_BO
# Working on:  DONEAR_BO
# Working on:  DRAGARWQ_BO
# Working on:  DRA_BO
# Working on:  DRCSYSTEMS_BO
# Working on:  DREDGECORP_BO
# Working on:  DRHABEEB_BO
# Working on:  DRL_BO
# Working on:  DRREDDY_BO
# Working on:  DSINVEST_BO
# Working on:  DSSL_BO
# Working on:  DUCON_BO
# Working on:  DUGARHOU_BO
# Working on:  DUKEOFS_BO
# Working on:  DUNCANENG_BO
# Working on:  DUROPACK_BO
# Working on:  DUROPLY_BO
# Working on:  DUTRON_BO
# Working on:  DVL_BO
# Working on:  DWARKESH_BO
# Working on:  DWL_BO
# Working on:  DYNAMATECH_BO
# Working on:  DYNAMICP_BO
# Working on:  DYNAMIC_BO
# Working on:  DYNAMIND_BO
# Working on:  DYNAVSN_BO
# Working on:  DYNPRO_BO
# Working on:  EARUM_BO
# Working on:  EASEMYTRIP_BO
# Working on:  EASTBUILD_BO
# Working on:  EASTRED_BO
# Working on:  EASTSILK_BO
# Working on:  EASTWEST_BO
# Working on:  EASUNREYRL_BO
# Working on:  EASUN_BO
# Working on:  ECLERX_BO
# Working on:  ECOBOAR_BO
# Working on:  ECOM_BO
# Working on:  ECOPLAST_BO
# Working on:  ECORECO_BO
# Working on:  ECSTSTL_BO
# Working on:  ECS_BO
# Working on:  EDELWEISS_BO
# Working on:  EDUCOMP_BO
# Working on:  EICHERMOT_BO
# Working on:  EIDPARRY_BO
# Working on:  EIHAHOTELS_BO
# Working on:  EIHOTEL_BO
# Working on:  EIKO_BO
# Working on:  EIMCOELECO_BO
# Working on:  EIS_BO
# Working on:  EKAMLEA_BO
# Working on:  EKC_BO
# Working on:  EKI_BO
# Working on:  ELAND_BO
# Working on:  ELANGO_BO
# Working on:  ELANTAS_BO
# Working on:  ELCIDIN_BO
# Working on:  ELDEHSG_BO
# Working on:  ELECON_BO
# Working on:  ELECTCAST_BO
# Working on:  ELECTHERM_BO
# Working on:  ELEFLOR_BO
# Working on:  ELEMARB_BO
# Working on:  ELGIEQUIP_BO
# Working on:  ELITECON_BO
# Working on:  ELIXIR_BO
# Working on:  ELLORATRAD_BO
# Working on:  ELNET_BO
# Working on:  ELPROINTL_BO
# Working on:  EMAINDIA_BO
# Working on:  EMAMILTD_BO
# Working on:  EMAMIPAP_BO
# Working on:  EMAMIREAL_BO
# Working on:  EMCO_BO
# Working on:  EMERALD_BO
# Working on:  EMERALL_BO
# Working on:  EMERGENT_BO
# Working on:  EMKAY_BO
# Working on:  EMMBI_BO
# Working on:  EMMESSA_BO
# Working on:  EMPIND_BO
# Working on:  ENBETRD_BO
# Working on:  ENDURANCE_BO
# Working on:  ENERGYDEV_BO
# Working on:  ENGINERSIN_BO
# Working on:  ENIL_BO
# Working on:  ENKEIWHEL_BO
# Working on:  ENTRINT_BO
# Working on:  ENVAIREL_BO
# Working on:  EPIC_BO
# Working on:  EPL_BO
# Working on:  EPSOMPRO_BO
# Working on:  EQUITASBNK_BO
# Working on:  EQUITAS_BO
# Working on:  ERIS_BO
# Working on:  EROSMEDIA_BO
# Working on:  ERPSOFT_BO
# Working on:  ESABINDIA_BO
# Working on:  ESARIND_BO
# Working on:  ESCORP_BO
# Working on:  ESCORTSFIN_BO
# Working on:  ESCORTS_BO
# Working on:  ESHAMEDIA_BO
# Working on:  ESSARSEC_BO
# Working on:  ESSARSHPNG_BO
# Working on:  ESTER_BO
# Working on:  ETIL_BO
# Working on:  ETT_BO
# Working on:  EUREKAI_BO
# Working on:  EUROASIA_BO
# Working on:  EUROLED_BO
# Working on:  EUROTEXIND_BO
# Working on:  EVANS_BO
# Working on:  EVEREADY_BO
# Working on:  EVERESTIND_BO
# Working on:  EVERESTO_BO
# Working on:  EVERLON_BO
# Working on:  EVERTEX_BO
# Working on:  EVEXIA_BO
# Working on:  EXCELINDUS_BO
# Working on:  EXCEL_BO
# Working on:  EXIDEIND_BO
# Working on:  EXPLEOSOL_BO
# Working on:  EXPLICITFIN_BO
# Working on:  EXPOGAS_BO
# Working on:  EXXARO_BO
# Working on:  FACORALL_BO
# Working on:  FACT_BO
# Working on:  FAIRCHEMOR_BO
# Working on:  FAZE3AUTO_BO
# Working on:  FAZE3Q_BO
# Working on:  FCL_BO
# Working on:  FCONSUMER_BO
# Working on:  FCSSOFT_BO
# Working on:  FDC_BO
# Working on:  FEDERALBNK_BO
# Working on:  FELDVR_BO
# Working on:  FEL_BO
# Working on:  FERMENTA_BO
# Working on:  FERVENTSYN_BO
# Working on:  FFPL_BO
# Working on:  FIBERWEB_BO
# Working on:  FIEMIND_BO
# Working on:  FILATEX_BO
# Working on:  FILATFASH_BO
# Working on:  FILTRA_BO
# Working on:  FINCABLES_BO
# Working on:  FINELINE_BO
# Working on:  FINEORG_BO
# Working on:  FINKURVE_BO
# Working on:  FINOLEXIND_BO
# Working on:  FIRSTOBJ_BO
# Working on:  FISCHER_BO
# Working on:  FIVEXTRADE_BO
# Working on:  FLEXFO_BO
# Working on:  FLEXITUFF_BO
# Working on:  FLFL_BO
# Working on:  FLOMIC_BO
# Working on:  FLORATX_BO
# Working on:  FLUIDOM_BO
# Working on:  FLUOROCHEM_BO
# Working on:  FMEC_BO
# Working on:  FMGOETZE_BO
# Working on:  FMNL_BO
# Working on:  FOCUS_BO
# Working on:  FOODSIN_BO
# Working on:  FORBESCO_BO
# Working on:  FORCEMOT_BO
# Working on:  FORINTL_BO
# Working on:  FORTISMLR_BO
# Working on:  FORTIS_BO
# Working on:  FOSECOIND_BO
# Working on:  FRANKLININD_BO
# Working on:  FRANKLIN_BO
# Working on:  FRASER_BO
# Working on:  FREDUN_BO
# Working on:  FRETAIL_BO
# Working on:  FRONTCAP_BO
# Working on:  FRONTCORP_BO
# Working on:  FRONTSP_BO
# Working on:  FRSHTRP_BO
# Working on:  FRUTION_BO
# Working on:  FSC_BO
# Working on:  FSL_BO
# Working on:  FUNDVISER_BO
# Working on:  FUTSOL_BO
# Working on:  FUTURSEC_BO
# Working on:  GABRIEL_BO
# Working on:  GAEL_BO
# Working on:  GAGANPO_BO
# Working on:  GAGAN_BO
# Working on:  GAIL_BO
# Working on:  GAJANANSEC_BO
# Working on:  GAJRA_BO
# Working on:  GALACTICO_BO
# Working on:  GALADAFIN_BO
# Working on:  GALADA_BO
# Working on:  GALAGEX_BO
# Working on:  GALAXYSURF_BO
# Working on:  GALLANTT_BO
# Working on:  GALLISPAT_BO
# Working on:  GALLOPENT_BO
# Working on:  GALXBRG_BO
# Working on:  GAL_BO
# Working on:  GANDHITUBE_BO
# Working on:  GANECOS_BO
# Working on:  GANESHBE_BO
# Working on:  GANESHHOUC_BO
# Working on:  GANGAPA_BO
# Working on:  GANGAPHARM_BO
# Working on:  GANGESSEC_BO
# Working on:  GANHOLD_BO
# Working on:  GANONPRO_BO
# Working on:  GARBIFIN_BO
# Working on:  GARFIBRES_BO
# Working on:  GARGFUR_BO
# Working on:  GARMNTMNTR_BO
# Working on:  GARNETINT_BO
# Working on:  GARNET_BO
# Working on:  GARODCH_BO
# Working on:  GARWAMAR_BO
# Working on:  GARWSYN_BO
# Working on:  GATI_BO
# Working on:  GAYAHWS_BO
# Working on:  GAYAPROJ_BO
# Working on:  GAYATRIBI_BO
# Working on:  GAYATRI_BO
# Working on:  GBLIL_BO
# Working on:  GCKL_BO
# Working on:  GCMCAPI_BO
# Working on:  GCMCOMM_BO
# Working on:  GCMSECU_BO
# Working on:  GCSL_BO
# Working on:  GDLLEAS_BO
# Working on:  GDL_BO
# Working on:  GDTRAGN_BO
# Working on:  GEECEE_BO
# Working on:  GEE_BO
# Working on:  GEL_BO
# Working on:  GEMSI_BO
# Working on:  GEMSPIN_BO
# Working on:  GENCON_BO
# Working on:  GENERAAGRI_BO
# Working on:  GENESIS_BO
# Working on:  GENESYS_BO
# Working on:  GENNEX_BO
# Working on:  GENPHARMA_BO
# Working on:  GENSOL_BO
# Working on:  GENUSPAPER_BO
# Working on:  GENUSPOWER_BO
# Working on:  GENUSPRIME_BO
# Working on:  GEOJITFSL_BO
# Working on:  GEPIL_BO
# Working on:  GESHIP_BO
# Working on:  GET&D_BO
# Working on:  GETALONG_BO
# Working on:  GFIL_BO
# Working on:  GFLLIMITED_BO
# Working on:  GGDANDE_BO
# Working on:  GGENG_BO
# Working on:  GGL_BO
# Working on:  GGPL_BO
# Working on:  GHCL_BO
# Working on:  GIANLIFE_BO
# Working on:  GICHSGFIN_BO
# Working on:  GICRE_BO
# Working on:  GILADAFINS_BO
# Working on:  GILLANDERS_BO
# Working on:  GILLETTE_BO
# Working on:  GINISILK_BO
# Working on:  GINNIFILA_BO
# Working on:  GIPCL_BO
# Working on:  GISOLUTION_BO
# Working on:  GITARENEW_BO
# Working on:  GKB_BO
# Working on:  GKCONS_BO
# Working on:  GKP_BO
# Working on:  GLANCE_BO
# Working on:  GLAND_BO
# Working on:  GLAXO_BO
# Working on:  GLCL_BO
# Working on:  GLENMARK_BO
# Working on:  GLFL_BO
# Working on:  GLITTEKG_BO
# Working on:  GLOBALCA_BO
# Working on:  GLOBALVECT_BO
# Working on:  GLOBOFFS_BO
# Working on:  GLOBUSCON_BO
# Working on:  GLOBUSSPR_BO
# Working on:  GLOSTERLTD_BO
# Working on:  GLS_BO
# Working on:  GMBREW_BO
# Working on:  GMDCLTD_BO
# Working on:  GMETCOAL_BO
# Working on:  GMM_BO
# Working on:  GMPL_BO
# Working on:  GMRINFRA_BO
# Working on:  GNA_BO
# Working on:  GNFC_BO
# Working on:  GNRL_BO
# Working on:  GOACARBON_BO
# Working on:  GOBLIN_BO
# Working on:  GOCLCORP_BO
# Working on:  GODAVARI_BO
# Working on:  GODFRYPHLP_BO
# Working on:  GODREJAGRO_BO
# Working on:  GODREJCP_BO
# Working on:  GODREJIND_BO
# Working on:  GODREJPROP_BO
# Working on:  GOENKA_BO
# Working on:  GOGIACAP_BO
# Working on:  GOKAKTEX_BO
# Working on:  GOKEX_BO
# Working on:  GOKULAGRO_BO
# Working on:  GOKUL_BO
# Working on:  GOLCA_BO
# Working on:  GOLDCOINHF_BO
# Working on:  GOLDCORP_BO
# Working on:  GOLDENCREST_BO
# Working on:  GOLDENTOBC_BO
# Working on:  GOLDIAM_BO
# Working on:  GOLDLINE_BO
# Working on:  GOLDTECH_BO
# Working on:  GOLECHA_BO
# Working on:  GOLKONDA_BO
# Working on:  GOLKUNDIA_BO
# Working on:  GOODLUCK_BO
# Working on:  GOODRICKE_BO
# Working on:  GOODYEAR_BO
# Working on:  GOPAIST_BO
# Working on:  GOPALA_BO
# Working on:  GORANIN_BO
# Working on:  GOTHIPL_BO
# Working on:  GOVNOW_BO
# Working on:  GOWRALE_BO
# Working on:  GOYALASS_BO
# Working on:  GPIL_BO
# Working on:  GPL_BO
# Working on:  GPPL_BO
# Working on:  GPTINFRA_BO
# Working on:  GRANDFONRY_BO
# Working on:  GRANULES_BO
# Working on:  GRAPHITE_BO
# Working on:  GRASIM_BO
# Working on:  GRATEXI_BO
# Working on:  GRAUWEIL_BO
# Working on:  GRAVISSHO_BO
# Working on:  GRAVITA_BO
# Working on:  GRAVITY_BO
# Working on:  GREAVESCOT_BO
# Working on:  GREENCREST_BO
# Working on:  GREENPANEL_BO
# Working on:  GREENPLY_BO
# Working on:  GREENPOWER_BO
# Working on:  GRINDWELL_BO
# Working on:  GRINFRA_BO
# Working on:  GRMOVER_BO
# Working on:  GRNLAMIND_BO
# Working on:  GROVY_BO
# Working on:  GRPLTD_BO
# Working on:  GRSE_BO
# Working on:  GRWRHITECH_BO
# Working on:  GSAUTO_BO
# Working on:  GSBFIN_BO
# Working on:  GSCLCEMENT_BO
# Working on:  GSFC_BO
# Working on:  GSLSEC_BO
# Working on:  GSPL_BO
# Working on:  GSS_BO
# Working on:  GSTL_BO
# Working on:  GTLINFRA_BO
# Working on:  GTL_BO
# Working on:  GTNINDS_BO
# Working on:  GTNTEX_BO
# Working on:  GTPL_BO
# Working on:  GTV_BO
# Working on:  GUFICBIO_BO
# Working on:  GUJALKALI_BO
# Working on:  GUJAPOLLO_BO
# Working on:  GUJARATPOLY_BO
# Working on:  GUJCMDS_BO
# Working on:  GUJCONT_BO
# Working on:  GUJCOTEX_BO
# Working on:  GUJCRAFT_BO
# Working on:  GUJCRED_BO
# Working on:  GUJGAS_BO
# Working on:  GUJHOTE_BO
# Working on:  GUJHYSPIN_BO
# Working on:  GUJINTRX_BO
# Working on:  GUJINV_BO
# Working on:  GUJPETR_BO
# Working on:  GUJRAFIA_BO
# Working on:  GUJSTATFIN_BO
# Working on:  GUJTERC_BO
# Working on:  GUJTHEM_BO
# Working on:  GULFOILLUB_BO
# Working on:  GULFPETRO_BO
# Working on:  GULPOLY_BO
# Working on:  GVBL_BO
# Working on:  GVFILM_BO
# Working on:  GYANDEV_BO
# Working on:  GYTRIPA_BO
# Working on:  HALDER_BO
# Working on:  HALDYNGL_BO
# Working on:  HAL_BO
# Working on:  HANMAN_BO
# Working on:  HAPPSTMNDS_BO
# Working on:  HARDCAS_BO
# Working on:  HARDWYN_BO
# Working on:  HARIAEXPO_BO
# Working on:  HARIGOV_BO
# Working on:  HARISH_BO
# Working on:  HARLETH_BO
# Working on:  HARRMALAYA_BO
# Working on:  HARYNACAP_BO
# Working on:  HASJUICE_BO
# Working on:  HASTIFIN_BO
# Working on:  HATHWAYB_BO
# Working on:  HATHWAY_BO
# Working on:  HATSUN_BO
# Working on:  HAVELLS_BO
# Working on:  HAVISHA_BO
# Working on:  HAWAENG_BO
# Working on:  HAWKINCOOK_BO
# Working on:  HAZOOR_BO
# Working on:  HBANKETF_BO
# Working on:  HBEL_BO
# Working on:  HBESD_BO
# Working on:  HBLEAS_BO
# Working on:  HBLPOWER_BO
# Working on:  HBPOR_BO
# Working on:  HBSTOCK_BO
# Working on:  HCC_BO
# Working on:  HCG_BO
# Working on:  HCKKVENTURE_BO
# Working on:  HCL-INSYS_BO
# Working on:  HCLTD_BO
# Working on:  HCLTECH_BO
# Working on:  HDFCAMC_BO
# Working on:  HDFCBANK_BO
# Working on:  HDFCLIFE_BO
# Working on:  HDFCNIFETF_BO
# Working on:  HDFC_BO
# Working on:  HDIL_BO
# Working on:  HEALINV_BO
# Working on:  HEERAISP_BO
# Working on:  HEG_BO
# Working on:  HEIDELBERG_BO
# Working on:  HELPAGE_BO
# Working on:  HEMANG_BO
# Working on:  HEMIPROP_BO
# Working on:  HEMORGANIC_BO
# Working on:  HEOFDD1100_BO
# Working on:  HEOFDD1126_BO
# Working on:  HEOFDG1100_BO
# Working on:  HEOFDG1126_BO
# Working on:  HEOFRD1100_BO
# Working on:  HEOFRD1126_BO
# Working on:  HEOFRG1100_BO
# Working on:  HEOFRG1126_BO
# Working on:  HERANBA_BO
# Working on:  HERCULES_BO
# Working on:  HERITGFOOD_BO
# Working on:  HEROMOTOCO_BO
# Working on:  HESTERBIO_BO
# Working on:  HEXATRADEX_BO
# Working on:  HFCL_BO
# Working on:  HFIL_BO
# Working on:  HGIND_BO
# Working on:  HGINFRA_BO
# Working on:  HGS_BO
# Working on:  HIGHENE_BO
# Working on:  HIGHSTREE_BO
# Working on:  HIKAL_BO
# Working on:  HIKLASS_BO
# Working on:  HILIKS_BO
# Working on:  HILTON_BO
# Working on:  HIL_BO
# Working on:  HIMATSEIDE_BO
# Working on:  HIMFIBP_BO
# Working on:  HIMTEK_BO
# Working on:  HINDADH_BO
# Working on:  HINDALCO_BO
# Working on:  HINDALUMI_BO
# Working on:  HINDAPL_BO
# Working on:  HINDBIO_BO
# Working on:  HINDCOMPOS_BO
# Working on:  HINDCOPPER_BO
# Working on:  HINDEVER_BO
# Working on:  HINDHARD_BO
# Working on:  HINDMILL_BO
# Working on:  HINDMOTORS_BO
# Working on:  HINDNATGLS_BO
# Working on:  HINDOILEXP_BO
# Working on:  HINDPETRO_BO
# Working on:  HINDTIN_BO
# Working on:  HINDUNILVR_BO
# Working on:  HINDZINC_BO
# Working on:  HINFLUR_BO
# Working on:  HIRAUTO_BO
# Working on:  HIRECT_BO
# Working on:  HISARMET_BO
# Working on:  HISARSP_BO
# Working on:  HITECHCORP_BO
# Working on:  HITECHGEAR_BO
# Working on:  HITECHWIND_BO
# Working on:  HITTCO_BO
# Working on:  HKG_BO
# Working on:  HLEGLAS_BO
# Working on:  HLVLTD_BO
# Working on:  HMT_BO
# Working on:  HMVL_BO
# Working on:  HNDFDS_BO
# Working on:  HOCL_BO
# Working on:  HOMEFIRST_BO
# Working on:  HONAUT_BO
# Working on:  HONDAPOWER_BO
# Working on:  HOTELRUGBY_BO
# Working on:  HOTLSILV_BO
# Working on:  HOVS_BO
# Working on:  HOWARHO_BO
# Working on:  HPCOTTON_BO
# Working on:  HPL_BO
# Working on:  HRMNYCP_BO
# Working on:  HRYNSHP_BO
# Working on:  HSCL_BO
# Working on:  HSIL_BO
# Working on:  HTMEDIA_BO
# Working on:  HUBTOWN_BO
# Working on:  HUDCO_BO
# Working on:  HUHTAMAKI_BO
# Working on:  HUIL_BO
# Working on:  HVL_BO
# Working on:  HYPERSOFT_BO
# Working on:  IBINFO_BO
# Working on:  IBREALEST_BO
# Working on:  IBRIGST_BO
# Working on:  IBULHSGFIN_BO
# Working on:  ICDSLTD_BO
# Working on:  ICICI500_BO
# Working on:  ICICIALPLV_BO
# Working on:  ICICIB22_BO
# Working on:  ICICIBANKN_BO
# Working on:  ICICIBANKP_BO
# Working on:  ICICIBANK_BO
# Working on:  ICICIFMCG_BO
# Working on:  ICICIGI_BO
# Working on:  ICICILOVOL_BO
# Working on:  ICICIM150_BO
# Working on:  ICICIMCAP_BO
# Working on:  ICICINF100_BO
# Working on:  ICICINIFTY_BO
# Working on:  ICICINV20_BO
# Working on:  ICICINXT50_BO
# Working on:  ICICIPHARM_BO
# Working on:  ICICIPRULI_BO
# Working on:  ICICISENSX_BO
# Working on:  ICICITECH_BO
# Working on:  ICIL_BO
# Working on:  ICLORGANIC_BO
# Working on:  ICRA_BO
# Working on:  ICSL_BO
# Working on:  IDBI_BO
# Working on:  IDEA_BO
# Working on:  IDFCEOS6DD_BO
# Working on:  IDFCEOS6DG_BO
# Working on:  IDFCEOS6RD_BO
# Working on:  IDFCEOS6RG_BO
# Working on:  IDFCFIRSTB_BO
# Working on:  IDFC_BO
# Working on:  IDFSENSEXE_BO
# Working on:  IDINFO_BO
# Working on:  IDM_BO
# Working on:  IEX_BO
# Working on:  IFBAGRO_BO
# Working on:  IFBIND_BO
# Working on:  IFCI_BO
# Working on:  IFGLEXPOR_BO
# Working on:  IFINSEC_BO
# Working on:  IFINSER_BO
# Working on:  IFL_BO
# Working on:  IGARASHI_BO
# Working on:  IGCIL_BO
# Working on:  IGLFXPL-B_BO
# Working on:  IGL_BO
# Working on:  IGPL_BO
# Working on:  IGRL_BO
# Working on:  IIFLSEC_BO
# Working on:  IIFLWAM_BO
# Working on:  IIFL_BO
# Working on:  IISL_BO
# Working on:  IITLPROJ_BO
# Working on:  IITL_BO
# Working on:  IKAB_BO
# Working on:  IL&FSENGG_BO
# Working on:  IL&FSTRANS_BO
# Working on:  IMAGICAA_BO
# Working on:  IMCAP_BO
# Working on:  IMEC_BO
# Working on:  IMFA_BO
# Working on:  IMPAL_BO
# Working on:  INANISEC_BO
# Working on:  INANI_BO
# Working on:  INCAP_BO
# Working on:  INCON_BO
# Working on:  INCREDIBLE_BO
# Working on:  INDAGIV_BO
# Working on:  INDAG_BO
# Working on:  INDBANK_BO
# Working on:  INDBNK_BO
# Working on:  INDCEMCAP_BO
# Working on:  INDCTST_BO
# Working on:  INDERGR_BO
# Working on:  INDGELA_BO
# Working on:  INDHOTEL_BO
# Working on:  INDIACEM_BO
# Working on:  INDIAGLYCO_BO
# Working on:  INDIAHOME_BO
# Working on:  INDIAMART_BO
# Working on:  INDIANACRY_BO
# Working on:  INDIANB_BO
# Working on:  INDIANCARD_BO
# Working on:  INDIANHUME_BO
# Working on:  INDIANVSH_BO
# Working on:  INDICAP_BO
# Working on:  INDIGOPNTS_BO
# Working on:  INDIGO_BO
# Working on:  INDINFO_BO
# Working on:  INDINFRA_BO
# Working on:  INDLEASE_BO
# Working on:  INDLMETER_BO
# Working on:  INDNIPPON_BO
# Working on:  INDOAMIN_BO
# Working on:  INDOASIAF_BO
# Working on:  INDOBORAX_BO
# Working on:  INDOCITY_BO
# Working on:  INDOCO_BO
# Working on:  INDOCRED_BO
# Working on:  INDOEURO_BO
# Working on:  INDOGLOBAL_BO
# Working on:  INDOKEM_BO
# Working on:  INDORAMA_BO
# Working on:  INDOSOLAR_BO
# Working on:  INDOSTAR_BO
# Working on:  INDOTECH_BO
# Working on:  INDOTHAI_BO
# Working on:  INDOUS_BO
# Working on:  INDOWIND_BO
# Working on:  INDPRUD_BO
# Working on:  INDRAIND_BO
# Working on:  INDRAMEDCO_BO
# Working on:  INDRANIB_BO
# Working on:  INDRENEW_BO
# Working on:  INDSILHYD_BO
# Working on:  INDSOYA_BO
# Working on:  INDSUCR_BO
# Working on:  INDSWFTLAB_BO
# Working on:  INDSWFTLTD_BO
# Working on:  INDTERRAIN_BO
# Working on:  INDTONER_BO
# Working on:  INDUSFINL_BO
# Working on:  INDUSINDBK_BO
# Working on:  INDUSTOWER_BO
# Working on:  INDXTRA_BO
# Working on:  INEOSSTYRO_BO
# Working on:  INERTIAST_BO
# Working on:  INFIBEAM_BO
# Working on:  INFLAME_BO
# Working on:  INFOMEDIA_BO
# Working on:  INFORTEC_BO
# Working on:  INFRABEES_BO
# Working on:  INFRAIND_BO
# Working on:  INFRONICS_BO
# Working on:  INFY_BO
# Working on:  INGERRAND_BO
# Working on:  INLCM_BO
# Working on:  INNOCORP_BO
# Working on:  INNOVATIVE_BO
# Working on:  INNOVATORS_BO
# Working on:  INNOVTEC_BO
# Working on:  INOVSYNTH_BO
# Working on:  INOXLEISUR_BO
# Working on:  INOXWIND_BO
# Working on:  INSECTICID_BO
# Working on:  INSILCO_BO
# Working on:  INSPIRISYS_BO
# Working on:  INTCAPM_BO
# Working on:  INTECCAP_BO
# Working on:  INTECH_BO
# Working on:  INTEGFD_BO
# Working on:  INTEGRAEN_BO
# Working on:  INTELLADV_BO
# Working on:  INTELLCAP_BO
# Working on:  INTELLECT_BO
# Working on:  INTELSOFT_BO
# Working on:  INTENTECH_BO
# Working on:  INTLCOMBQ_BO
# Working on:  INTLCONV_BO
# Working on:  INTRGLB_BO
# Working on:  INTSTOIL_BO
# Working on:  INVENTURE_BO
# Working on:  INVPRECQ_BO
# Working on:  IOB_BO
# Working on:  IOC_BO
# Working on:  IOLCP_BO
# Working on:  IONEXCHANG_BO
# Working on:  IOSYSTEM_BO
# Working on:  IPCALAB_BO
# Working on:  IPL_BO
# Working on:  IPRINGLTD_BO
# Working on:  IPRU3095_BO
# Working on:  IPRU3096_BO
# Working on:  IPRU3143_BO
# Working on:  IPRU3144_BO
# Working on:  IPRU3168_BO
# Working on:  IPRU3169_BO
# Working on:  IPRU3218_BO
# Working on:  IPRU3219_BO
# Working on:  IPRU9297_BO
# Working on:  IPRU9298_BO
# Working on:  IPRU9345_BO
# Working on:  IPRU9346_BO
# Working on:  IPRU9370_BO
# Working on:  IPRU9371_BO
# Working on:  IPRU9420_BO
# Working on:  IPRU9421_BO
# Working on:  IRB_BO
# Working on:  IRCON_BO
# Working on:  IRCTC_BO
# Working on:  IRFC_BO
# Working on:  IRIS_BO
# Working on:  IRONWOOD_BO
# Working on:  ISEC_BO
# Working on:  ISFL_BO
# Working on:  ISFT_BO
# Working on:  ISGEC_BO
# Working on:  ISHANCH_BO
# Working on:  ISHITADR_BO
# Working on:  ISHWATR_BO
# Working on:  ISLCONSUL_BO
# Working on:  ISMTLTD_BO
# Working on:  ISTLTD_BO
# Working on:  ISTRNETWK_BO
# Working on:  ISWL_BO
# Working on:  ITC_BO
# Working on:  ITDCEM_BO
# Working on:  ITDC_BO
# Working on:  ITHL_BO
# Working on:  ITI_BO
# Working on:  ITL_BO
# Working on:  IVC_BO
# Working on:  IVP_BO
# Working on:  IWEL_BO
# Working on:  IWP_BO
# Working on:  IYKOTHITE_BO
# Working on:  IZMO_BO
# Working on:  J&KBANK_BO
# Working on:  JAGAJITIND_BO
# Working on:  JAGANLAM_BO
# Working on:  JAGRAN_BO
# Working on:  JAGSNPHARM_BO
# Working on:  JAGSONFI_BO
# Working on:  JAIBALAJI_BO
# Working on:  JAICORPLTD_BO
# Working on:  JAIHINDS_BO
# Working on:  JAINCO_BO
# Working on:  JAINEX_BO
# Working on:  JAINMARMO_BO
# Working on:  JAINSTUDIO_BO
# Working on:  JAIPAN_BO
# Working on:  JAMESWARREN_BO
# Working on:  JAMNAAUTO_BO
# Working on:  JAMSHRI_BO
# Working on:  JANUSCORP_BO
# Working on:  JASCH_BO
# Working on:  JATALIA_BO
# Working on:  JATTAINDUS_BO
# Working on:  JAUSPOL_BO
# Working on:  JAYAGROGN_BO
# Working on:  JAYATMA_BO
# Working on:  JAYBARMARU_BO
# Working on:  JAYBHCR_BO
# Working on:  JAYCH_BO
# Working on:  JAYIND_BO
# Working on:  JAYKAY_BO
# Working on:  JAYNECOIND_BO
# Working on:  JAYSHREETEA_BO
# Working on:  JAYSYN_BO
# Working on:  JAYUSH_BO
# Working on:  JBCHEPHARM_BO
# Working on:  JBFIND_BO
# Working on:  JBMA_BO
# Working on:  JCHAC_BO
# Working on:  JCTLTD_BO
# Working on:  JDORGOCHEM_BO
# Working on:  JEL_BO
# Working on:  JENBURPH_BO
# Working on:  JETAIRWAYS_BO
# Working on:  JETINFRA_BO
# Working on:  JETKINGQ_BO
# Working on:  JETMALL_BO
# Working on:  JFL_BO
# Working on:  JHACC_BO
# Working on:  JHS_BO
# Working on:  JIGAR_BO
# Working on:  JIKIND_BO
# Working on:  JINAAM_BO
# Working on:  JINDALPHOT_BO
# Working on:  JINDALPOLY_BO
# Working on:  JINDALSAW_BO
# Working on:  JINDALSTEL_BO
# Working on:  JINDCAP_BO
# Working on:  JINDHOT_BO
# Working on:  JINDRILL_BO
# Working on:  JINDWORLD_BO
# Working on:  JISLDVREQS_BO
# Working on:  JISLJALEQS_BO
# Working on:  JITFINFRA_BO
# Working on:  JJFINCOR_BO
# Working on:  JK AGRI_BO
# Working on:  JKCEMENT_BO
# Working on:  JKIL_BO
# Working on:  JKLAKSHMI_BO
# Working on:  JKPAPER_BO
# Working on:  JKTYRE_BO
# Working on:  JLL_BO
# Working on:  JLMORI_BO
# Working on:  JMCPROJECT_BO
# Working on:  JMFINANCIL_BO
# Working on:  JMGCORP_BO
# Working on:  JMTAUTOLTD_BO
# Working on:  JOHNPHARMA_BO
# Working on:  JOINDRE_BO
# Working on:  JOINTECAED_BO
# Working on:  JONJUA_BO
# Working on:  JOONKTOLL_BO
# Working on:  JOSTS_BO
# Working on:  JOYREALTY_BO
# Working on:  JPASSOCIAT_BO
# Working on:  JPINFRATEC_BO
# Working on:  JPOLYINVST_BO
# Working on:  JPPOWER_BO
# Working on:  JPTRLES_BO
# Working on:  JPTSEC_BO
# Working on:  JRELTD_BO
# Working on:  JRFOODS_BO
# Working on:  JSGLEASING_BO
# Working on:  JSHL_BO
# Working on:  JSLHISAR_BO
# Working on:  JSLINDL_BO
# Working on:  JSL_BO
# Working on:  JSTL_BO
# Working on:  JSWENERGY_BO
# Working on:  JSWHL_BO
# Working on:  JSWISPL_BO
# Working on:  JSWSTEEL_BO
# Working on:  JTAPARIA_BO
# Working on:  JTEKTINDIA_BO
# Working on:  JTLINFRA_BO
# Working on:  JUBLFOOD_BO
# Working on:  JUBLINDS_BO
# Working on:  JUBLINGREA_BO
# Working on:  JUBLPHARMA_BO
# Working on:  JUMBFNL_BO
# Working on:  JUMBO_BO
# Working on:  JUMPNET_BO
# Working on:  JUNIORBEES_BO
# Working on:  JUPITERIN_BO
# Working on:  JUSTDIAL_BO
# Working on:  JYOTHYLAB_BO
# Working on:  JYOTIN_BO
# Working on:  JYOTIRES_BO
# Working on:  JYOTISTRUC_BO
# Working on:  JYOTI_BO
# Working on:  KAARYAFSL_BO
# Working on:  KABRAEXTRU_BO
# Working on:  KABSON_BO
# Working on:  KACHCHH_BO
# Working on:  KACL_BO
# Working on:  KAIRA_BO
# Working on:  KAJARIACER_BO
# Working on:  KAJARIR_BO
# Working on:  KAKATCEM_BO
# Working on:  KAKTEX_BO
# Working on:  KALLAM_BO
# Working on:  KALPATPOWR_BO
# Working on:  KALYANIFRG_BO
# Working on:  KALYANKJIL_BO
# Working on:  KAMADGIRI_BO
# Working on:  KAMAHOLD_BO
# Working on:  KAMANWALA_BO
# Working on:  KAMATHOTEL_BO
# Working on:  KAMDHENU_BO
# Working on:  KAMRLAB_BO
# Working on:  KANANIIND_BO
# Working on:  KANCHI_BO
# Working on:  KANCOTEA_BO
# Working on:  KANDAGIRI_BO
# Working on:  KANELIND_BO
# Working on:  KANORICHEM_BO
# Working on:  KANPRPLA_BO
# Working on:  KANSAFB_BO
# Working on:  KANSAINER_BO
# Working on:  KANSHST_BO
# Working on:  KANUNGO_BO
# Working on:  KAPASHI_BO
# Working on:  KAPILCO_BO
# Working on:  KAPILRAJ_BO
# Working on:  KARANWO_BO
# Working on:  KARDA_BO
# Working on:  KARMAENG_BO
# Working on:  KARNAVATI_BO
# Working on:  KARTKIN_BO
# Working on:  KARURVYSYA_BO
# Working on:  KATRSPG_BO
# Working on:  KAUSHALYA_BO
# Working on:  KAVVERITEL_BO
# Working on:  KAYA_BO
# Working on:  KAYCEEI_BO
# Working on:  KAYPOWR_BO
# Working on:  KBSINDIA_BO
# Working on:  KCDGROUP_BO
# Working on:  KCLINFRA_BO
# Working on:  KCL_BO
# Working on:  KCPSUGIND_BO
# Working on:  KCP_BO
# Working on:  KCSL_BO
# Working on:  KDDL_BO
# Working on:  KDLL_BO
# Working on:  KDML_BO
# Working on:  KECL_BO
# Working on:  KEC_BO
# Working on:  KEDIACN_BO
# Working on:  KEERTHI_BO
# Working on:  KEI_BO
# Working on:  KELENRG_BO
# Working on:  KELLTONTEC_BO
# Working on:  KEL_BO
# Working on:  KEMISTAR_BO
# Working on:  KEMP_BO
# Working on:  KENNAMET_BO
# Working on:  KENVI_BO
# Working on:  KERALAYUR_BO
# Working on:  KERNEX_BO
# Working on:  KESARENT_BO
# Working on:  KESORAMIND_BO
# Working on:  KEYCORP_BO
# Working on:  KEYFINSER_BO
# Working on:  KFBL_BO
# Working on:  KGDENIM_BO
# Working on:  KGPETRO_BO
# Working on:  KHADIM_BO
# Working on:  KHAICHEM_BO
# Working on:  KHAITANLTD_BO
# Working on:  KHANDSE_BO
# Working on:  KHODAY_BO
# Working on:  KHYATI_BO
# Working on:  KICL_BO
# Working on:  KIDUJA_BO
# Working on:  KIFS_BO
# Working on:  KILITCH_BO
# Working on:  KILPEST_BO
# Working on:  KIMIABL_BO
# Working on:  KIMS_BO
# Working on:  KINETICENG_BO
# Working on:  KINETRU_BO
# Working on:  KINGFA_BO
# Working on:  KINGSINFR_BO
# Working on:  KIOCL_BO
# Working on:  KIRANPR_BO
# Working on:  KIRANSY-B_BO
# Working on:  KIRANVYPAR_BO
# Working on:  KIRIINDUS_BO
# Working on:  KIRLFER_BO
# Working on:  KIRLOSBROS_BO
# Working on:  KIRLOSENG_BO
# Working on:  KIRLOSIND_BO
# Working on:  KIRLPNU_BO
# Working on:  KISAN_BO
# Working on:  KITEX_BO
# Working on:  KJMCCORP_BO
# Working on:  KJMCFIN_BO
# Working on:  KKALPANAIND_BO
# Working on:  KKCL_BO
# Working on:  KKFIN_BO
# Working on:  KKPLASTICK_BO
# Working on:  KLBRENG-B_BO
# Working on:  KLGCAP_BO
# Working on:  KLKELEC_BO
# Working on:  KLRFM_BO
# Working on:  KMCSHIL_BO
# Working on:  KMEW_BO
# Working on:  KMFBLDR_BO
# Working on:  KMGMILK_BO
# Working on:  KMSMEDI_BO
# Working on:  KMSUGAR_BO
# Working on:  KNRCON_BO
# Working on:  KOBO_BO
# Working on:  KOCL_BO
# Working on:  KOKUYOCMLN_BO
# Working on:  KOLTEPATIL_BO
# Working on:  KONARKSY_BO
# Working on:  KONNDOR_BO
# Working on:  KOPRAN_BO
# Working on:  KORE_BO
# Working on:  KOTAKBANK_BO
# Working on:  KOTAKNIFTY_BO
# Working on:  KOTAKPSUBK_BO
# Working on:  KOTHARIPRO_BO
# Working on:  KOVAI_BO
# Working on:  KPEL_BO
# Working on:  KPIGLOBAL_BO
# Working on:  KPITTECH_BO
# Working on:  KPL_BO
# Working on:  KPRMILL_BO
# Working on:  KPT_BO
# Working on:  KRANTI_BO
# Working on:  KRATOSENER_BO
# Working on:  KRBL_BO
# Working on:  KREBSBIO_BO
# Working on:  KREONFIN_BO
# Working on:  KRETTOSYS_BO
# Working on:  KRIFILIND_BO
# Working on:  KRIINFRA_BO
# Working on:  KRISHNACAP_BO
# Working on:  KRISHNA_BO
# Working on:  KRITIIND_BO
# Working on:  KRITINUT_BO
# Working on:  KRL_BO
# Working on:  KRRAIL_BO
# Working on:  KRSNAA_BO
# Working on:  KRYPTONQ_BO
# Working on:  KSB_BO
# Working on:  KSCL_BO
# Working on:  KSE_BO
# Working on:  KSL_BO
# Working on:  KTIL_BO
# Working on:  KTINDF4DD_BO
# Working on:  KTINDF4DG_BO
# Working on:  KTINDF4RD_BO
# Working on:  KTINDF4RG_BO
# Working on:  KTKBANK_BO
# Working on:  KTKSENSEX_BO
# Working on:  KUANTUM_BO
# Working on:  KUBERJI_BO
# Working on:  KUNSTOFF_BO
# Working on:  KUSHAL_BO
# Working on:  KUSHIND_BO
# Working on:  KUSUMEL_BO
# Working on:  KUWERIN_BO
# Working on:  KZLFIN_BO
# Working on:  L&TFH_BO
# Working on:  LACTOSE_BO
# Working on:  LADDERUP_BO
# Working on:  LADIAMO_BO
# Working on:  LAFFANSQ_BO
# Working on:  LAHL_BO
# Working on:  LAHOTIOV_BO
# Working on:  LAKHOTIA_BO
# Working on:  LAKPRE_BO
# Working on:  LAKSELEC_BO
# Working on:  LAKSHMIMIL_BO
# Working on:  LALPATHLAB_BO
# Working on:  LAL_BO
# Working on:  LAMBODHARA_BO
# Working on:  LANCER_BO
# Working on:  LANCORHOL_BO
# Working on:  LAOPALA_BO
# ...
# Working on:  STARLIT_BO
# Working on:  STARLOG_BO
# Working on:  STARPAPER_BO
# Working on:  STARTECK_BO
# Working on:  STAR_BO
# Working on:  STCINDIA_BO
# Working on:  STCORP_BO
# Working on:  STDBAT_BO
# Working on:  STDSFAC_BO
# Working on:  STDSHOE_BO
# Working on:  STEELCAS_BO
# Working on:  STEELXIND_BO
# Working on:  STELLANT_BO
# Working on:  STELLAR_BO
# Working on:  STEL_BO
# Working on:  STEP2COR_BO
# Working on:  STEPHANOTIS_BO
# Working on:  STERTOOLS_BO
# Working on:  STHINPA_BO
# Working on:  STLSTRINF_BO
# Working on:  STLTECH_BO
# Working on:  STL_BO
# Working on:  STOVACQ_BO
# Working on:  STOVEKRAFT_BO
# Working on:  STRAEXPO_BO
# Working on:  STRATMONT_BO
# Working on:  STRGRENWO_BO
# Working on:  STRIPMT_BO
# Working on:  STRLGUA_BO
# Working on:  STURDY_BO
# Working on:  STYLAMIND_BO
# Working on:  SUBEX_BO
# Working on:  SUBROS_BO
# Working on:  SUBSM_BO
# Working on:  SUCHITRA_BO
# Working on:  SUCROSA_BO
# Working on:  SUDAI_BO
# Working on:  SUDARSCHEM_BO
# Working on:  SUDTIND-B_BO
# Working on:  SUERYAAKNI_BO
# Working on:  SUGALDAM_BO
# Working on:  SUJALA_BO
# Working on:  SUKHJITS_BO
# Working on:  SULABEN_BO
# Working on:  SUMEDHA_BO
# Working on:  SUMEETINDS_BO
# Working on:  SUMERUIND_BO
# Working on:  SUMICHEM_BO
# Working on:  SUMMITSEC_BO
# Working on:  SUNCITYSY_BO
# Working on:  SUNCLAYLTD_BO
# Working on:  SUNDARAM_BO
# Working on:  SUNDARMFIN_BO
# Working on:  SUNDRMBRAK_BO
# Working on:  SUNDRMFAST_BO
# Working on:  SUNEDISON_BO
# Working on:  SUNFLAG_BO
# Working on:  SUNGOLD_BO
# Working on:  SUNILAGR_BO
# Working on:  SUNILTX_BO
# Working on:  SUNLOC_BO
# Working on:  SUNPHARMA_BO
# Working on:  SUNRAJDI_BO
# Working on:  SUNRETAIL_BO
# Working on:  SUNRINV_BO
# Working on:  SUNSHIEL_BO
# Working on:  SUNTECK_BO
# Working on:  SUNTV_BO
# Working on:  SUPERBAK_BO
# Working on:  SUPERHOUSE_BO
# Working on:  SUPERIOR_BO
# Working on:  SUPERNOVA_BO
# Working on:  SUPERSHAKT_BO
# Working on:  SUPERSPIN_BO
# Working on:  SUPERTEX_BO
# Working on:  SUPER_BO
# Working on:  SUPPETRO_BO
# Working on:  SUPRAJIT_BO
# Working on:  SUPRAP_BO
# Working on:  SUPRATRE_BO
# Working on:  SUPRBPA_BO
# Working on:  SUPREMEIND_BO
# Working on:  SUPREMEX_BO
# Working on:  SUPREME_BO
# Working on:  SUPTANERY_BO
# Working on:  SURAJLTD_BO
# Working on:  SURAJ_BO
# Working on:  SURANASOL_BO
# Working on:  SURANAT&P_BO
# Working on:  SURATEX_BO
# Working on:  SURBHIN_BO
# Working on:  SURFI_BO
# Working on:  SURJIND_BO
# Working on:  SURYAAMBA_BO
# Working on:  SURYACHAKRA_BO
# Working on:  SURYAINDIA_BO
# Working on:  SURYAKR_BO
# Working on:  SURYALAXMI_BO
# Working on:  SURYALA_BO
# Working on:  SURYAROSNI_BO
# Working on:  SURYODAY_BO
# Working on:  SURYVANSP_BO
# Working on:  SUTLEJTEX_BO
# Working on:  SUUMAYA_BO
# Working on:  SUVENPHAR_BO
# Working on:  SUVEN_BO
# Working on:  SUVIDHAA_BO
# Working on:  SUYOG_BO
# Working on:  SUZLON_BO
# Working on:  SVAINDIA_BO
# Working on:  SVAMSOF_BO
# Working on:  SVARTCORP_BO
# Working on:  SVCIND_BO
# Working on:  SVGLOBAL_BO
# Working on:  SVPGLOB_BO
# Working on:  SVPHOUSING_BO
# Working on:  SVRL_BO
# Working on:  SW1_BO
# Working on:  SWADEIN_BO
# Working on:  SWADPOL_BO
# Working on:  SWANENERGY_BO
# Working on:  SWARAJENG_BO
# Working on:  SWARNSAR_BO
# Working on:  SWASTIKA_BO
# Working on:  SWASTIVI_BO
# Working on:  SWELECTES_BO
# Working on:  SWITCHTE_BO
# Working on:  SWORDEDGE_BO
# Working on:  SWRNASE_BO
# Working on:  SWSOLAR_BO
# Working on:  SXETF_BO
# Working on:  SYBLY_BO
# Working on:  SYLPH_BO
# Working on:  SYMBIOX_BO
# Working on:  SYMPHONY_BO
# Working on:  SYNCOMF_BO
# Working on:  SYNGENE_BO
# Working on:  SYNTHFO_BO
# Working on:  SYSCHEM_BO
# Working on:  SYSTMTXC_BO
# Working on:  SYTIXSE_BO
# Working on:  TAALENT_BO
# Working on:  TAAZAINT_BO
# Working on:  TAIIND_BO
# Working on:  TAINWALCHM_BO
# Working on:  TAJGVK_BO
# Working on:  TAKE_BO
# Working on:  TALBROAUTO_BO
# Working on:  TALBROSENG_BO
# Working on:  TAMBOLI_BO
# Working on:  TANAA_BO
# Working on:  TANFACIND_BO
# Working on:  TANLA_BO
# Working on:  TANTIACONS_BO
# Working on:  TANVI_BO
# Working on:  TAPARIA_BO
# Working on:  TARAI_BO
# Working on:  TARAPUR_BO
# Working on:  TARC_BO
# Working on:  TARINI_BO
# Working on:  TARMAT_BO
# Working on:  TASHIND_BO
# Working on:  TASTYBIT_BO
# Working on:  TATACHEM_BO
# Working on:  TATACOFFEE_BO
# Working on:  TATACOMM_BO
# Working on:  TATACONSUM_BO
# Working on:  TATAELXSI_BO
# Working on:  TATAINVEST_BO
# Working on:  TATAMETALI_BO
# Working on:  TATAMOTORS_BO
# Working on:  TATAMTRDVR_BO
# Working on:  TATAPOWER_BO
# Working on:  TATASTEEL_BO
# Working on:  TATASTLBSL_BO
# Working on:  TATASTLLP_BO
# Working on:  TATAYODOGA_BO
# Working on:  TATIAGLOB_BO
# Working on:  TATVA_BO
# Working on:  TAVERNIER_BO
# Working on:  TBZ_BO
# Working on:  TCFCFINQ_BO
# Working on:  TCIDEVELOP_BO
# Working on:  TCIEXP_BO
# Working on:  TCIFINANCE_BO
# Working on:  TCIIND_BO
# Working on:  TCI_BO
# Working on:  TCMLMTD_BO
# Working on:  TCNSBRANDS_BO
# Working on:  TCPLPACK_BO
# Working on:  TCS_BO
# Working on:  TDPOWERSYS_BO
# Working on:  TDSL_BO
# Working on:  TEAMLEASE_BO
# Working on:  TEATIME_BO
# Working on:  TECHCON_BO
# Working on:  TECHIN_BO
# Working on:  TECHM_BO
# Working on:  TECHNOE_BO
# Working on:  TECHNVISN_BO
# Working on:  TEJASNET_BO
# Working on:  TEJASSVI_BO
# Working on:  TEJNAKSH_BO
# Working on:  TELECANOR_BO
# Working on:  TERAI_BO
# Working on:  TERASOFT_BO
# Working on:  TERRAFORM_BO
# Working on:  TERRAREAL_BO
# Working on:  TERRASCOPE_BO
# Working on:  TEXELIN_BO
# Working on:  TEXINFRA_BO
# Working on:  TEXMOPIPES_BO
# Working on:  TEXRAIL_BO
# Working on:  TFCILTD_BO
# Working on:  TFLL_BO
# Working on:  TFL_BO
# Working on:  TFSL_BO
# Working on:  TGBHOTELS_BO
# Working on:  TGVSL_BO
# Working on:  THACKER_BO
# Working on:  THAKDEV_BO
# Working on:  THAKRAL_BO
# Working on:  THAMBBI_BO
# Working on:  THANGAMAYL_BO
# Working on:  THEBYKE_BO
# Working on:  THEINVEST_BO
# Working on:  THEMISMED_BO
# Working on:  THERMAX_BO
# Working on:  THINKINK_BO
# Working on:  THIRDFIN_BO
# Working on:  THOMASCOOK_BO
# Working on:  THOMASCOTT_BO
# Working on:  THYROCARE_BO
# Working on:  TIAANC_BO
# Working on:  TIDEWATER_BO
# Working on:  TIGERLOGS_BO
# Working on:  TIGLOB_BO
# Working on:  TIIL_BO
# Working on:  TIINDIA_BO
# Working on:  TIJARIA_BO
# Working on:  TILAK_BO
# Working on:  TIL_BO
# Working on:  TIMESGREEN_BO
# Working on:  TIMESGTY_BO
# Working on:  TIMETECHNO_BO
# Working on:  TIMEX_BO
# Working on:  TIMKEN_BO
# Working on:  TINNARUBR_BO
# Working on:  TINNATFL_BO
# Working on:  TINPLATE_BO
# Working on:  TIPSINDLTD_BO
# Working on:  TIRSARJ_BO
# Working on:  TIRUFOAM_BO
# Working on:  TIRUMALCHM_BO
# Working on:  TIRUSTA_BO
# Working on:  TITAANIUM_BO
# Working on:  TITANBIO_BO
# Working on:  TITANSEC_BO
# Working on:  TITAN_BO
# Working on:  TI_BO
# Working on:  TMRVL_BO
# Working on:  TMTIND-B1_BO
# Working on:  TNPETRO_BO
# Working on:  TNPL_BO
# Working on:  TNSTLTU_BO
# Working on:  TNTELE_BO
# Working on:  TOKYOFIN_BO
# Working on:  TOKYOPLAST_BO
# Working on:  TORNTPHARM_BO
# Working on:  TORNTPOWER_BO
# Working on:  TOYAMIND_BO
# Working on:  TPLPLAST_BO
# Working on:  TPROJECT_BO
# Working on:  TRABI_BO
# Working on:  TRADWIN_BO
# Working on:  TRANOCE_BO
# Working on:  TRANSASIA_BO
# Working on:  TRANSCHEM_BO
# Working on:  TRANSCOR_BO
# Working on:  TRANSFD_BO
# Working on:  TRANSFIN_BO
# Working on:  TRANSFRE_BO
# Working on:  TRANSPEK_BO
# Working on:  TRCFIN_BO
# Working on:  TREEHOUSE_BO
# Working on:  TREJHARA_BO
# Working on:  TRENT_BO
# Working on:  TRESCON_BO
# Working on:  TRF_BO
# Working on:  TRICOMFRU_BO
# Working on:  TRIDENT_BO
# Working on:  TRIDETOOL_BO
# Working on:  TRIGYN_BO
# Working on:  TRIJAL_BO
# Working on:  TRIL_BO
# Working on:  TRIMURTHI_BO
# Working on:  TRINITYLEA_BO
# Working on:  TRIOMERC_BO
# Working on:  TRIPR_BO
# Working on:  TRISHAKT_BO
# Working on:  TRITONV_BO
# Working on:  TRITURBINE_BO
# Working on:  TRIVENIENT_BO
# Working on:  TRIVENIGQ_BO
# Working on:  TRIVENI_BO
# Working on:  TRIVIKRAMA_BO
# Working on:  TRL_BO
# Working on:  TSPIRITUAL_BO
# Working on:  TTFL_BO
# Working on:  TTIENT_BO
# Working on:  TTIL_BO
# Working on:  TTKHEALTH_BO
# Working on:  TTKPRESTIG_BO
# Working on:  TTLEL_BO
# Working on:  TTL_BO
# Working on:  TTML_BO
# Working on:  TULASEEBIOE_BO
# Working on:  TULIVE_BO
# Working on:  TUNITEX_BO
# Working on:  TUTIALKA_BO
# Working on:  TV18BRDCST_BO
# Working on:  TVOLCON_BO
# Working on:  TVSELECT_BO
# Working on:  TVSMOTOR_BO
# Working on:  TVSSRICHAK_BO
# Working on:  TVTODAY_BO
# Working on:  TVVISION_BO
# Working on:  TWINSTAR_BO
# Working on:  TWIROST_BO
# Working on:  TWL_BO
# Working on:  TYCHE_BO
# Working on:  TYROON_BO
# Working on:  UBL_BO
# Working on:  UCALFUEL_BO
# Working on:  UCOBANK_BO
# Working on:  UDAICEMENT_BO
# Working on:  UDAYJEW_BO
# Working on:  UFLEX_BO
# Working on:  UFO_BO
# Working on:  UGARSUGAR_BO
# Working on:  UGROCAP_BO
# Working on:  UHZAVERI_BO
# Working on:  UJAAS_BO
# Working on:  UJJIVANSFB_BO
# Working on:  UJJIVAN_BO
# Working on:  ULTRACAB_BO
# Working on:  ULTRACEMCO_BO
# Working on:  ULTRAMAR_BO
# Working on:  UMANGDAIR_BO
# Working on:  UMESLTD_BO
# Working on:  UMIYA_BO
# Working on:  UNIABEXAL_BO
# Working on:  UNIAUTO_BO
# Working on:  UNICHEMLAB_BO
# Working on:  UNICK_BO
# Working on:  UNIDT_BO
# Working on:  UNIJOLL_BO
# Working on:  UNIMOVR_BO
# Working on:  UNIONBANK_BO
# Working on:  UNIPHOS_BO
# Working on:  UNIQUEO_BO
# Working on:  UNIROYAL_BO
# Working on:  UNISHIRE_BO
# Working on:  UNISON_BO
# Working on:  UNISTRMU_BO
# Working on:  UNITDCR_BO
# Working on:  UNITDSPR_BO
# Working on:  UNITECH_BO
# Working on:  UNITEDINT_BO
# Working on:  UNITEDTE_BO
# Working on:  UNITINT_BO
# Working on:  UNIVCABLES_BO
# Working on:  UNIVPHOTO_BO
# Working on:  UNIVSTAR_BO
# Working on:  UNIWORTH_BO
# Working on:  UNIWSEC_BO
# Working on:  UNJHAFOR_BO
# Working on:  UNQTYMI_BO
# Working on:  UNRYLMA_BO
# Working on:  UNTTEMI_BO
# Working on:  UPASAFN_BO
# Working on:  UPL_BO
# Working on:  UPSURGE_BO
# Working on:  URJAGLOBA_BO
# Working on:  USGTECH_BO
# Working on:  USHAKIRA_BO
# Working on:  USHAMART_BO
# Working on:  USHDI_BO
# Working on:  UTIAMC_BO
# Working on:  UTIBANKETF_BO
# Working on:  UTINEXT50_BO
# Working on:  UTINIFTETF_BO
# Working on:  UTIQUE_BO
# Working on:  UTISENSETF_BO
# Working on:  UTISXN50_BO
# Working on:  UTLINDS_BO
# Working on:  UTTAMSTL_BO
# Working on:  UTTAMSUGAR_BO
# Working on:  UVDRHOR_BO
# Working on:  UYFINCORP_BO
# Working on:  V2RETAIL_BO
# Working on:  VAARAD_BO
# Working on:  VADILALIND_BO
# Working on:  VADILENT_BO
# Working on:  VAGHANI_BO
# Working on:  VAIBHAVGBL_BO
# Working on:  VAKRANGEE_BO
# Working on:  VALIANTORG_BO
# Working on:  VALIANT_BO
# Working on:  VALLABHSQ_BO
# Working on:  VALLEY_BO
# Working on:  VALSONQ_BO
# Working on:  VAL_BO
# Working on:  VAMA_BO
# Working on:  VAMSHIRU_BO
# Working on:  VANDANA_BO
# Working on:  VANICOM_BO
# Working on:  VANTABIO_BO
# Working on:  VAPIPPR_BO
# Working on:  VARDHANCFL_BO
# Working on:  VARDHMAN_BO
# Working on:  VARDMNPOLY_BO
# Working on:  VARIMAN_BO
# Working on:  VARROC_BO
# Working on:  VARUNME_BO
# Working on:  VASCONEQ_BO
# Working on:  VASINFRA_BO
# Working on:  VASWANI_BO
# Working on:  VBCFERROQ_BO
# Working on:  VBDESAI_BO
# Working on:  VBL_BO
# Working on:  VCU_BO
# Working on:  VEDAVAAG_BO
# Working on:  VEDL_BO
# Working on:  VEERENRGY_BO
# Working on:  VEERHEALTH_BO
# Working on:  VEGETABLE_BO
# Working on:  VELHO_BO
# Working on:  VELJAN_BO
# Working on:  VENKYS_BO
# Working on:  VENLONENT_BO
# Working on:  VENUSREM_BO
# Working on:  VERITAS_BO
# Working on:  VERTEX_BO
# Working on:  VESUVIUS_BO
# Working on:  VETO_BO
# Working on:  VFL_BO
# Working on:  VGCL_BO
# Working on:  VGIL_BO
# Working on:  VGUARD_BO
# Working on:  VHL_BO
# Working on:  VIAANINDUS_BO
# Working on:  VICEROY_BO
# Working on:  VICTMILL_BO
# Working on:  VICTORYPP_BO
# Working on:  VIDHIING_BO
# Working on:  VIDLI_BO
# Working on:  VIJAYA_BO
# Working on:  VIJAYTX_BO
# Working on:  VIJSOLX_BO
# Working on:  VIKALPS_BO
# Working on:  VIKASECO_BO
# Working on:  VIKASLIFE_BO
# Working on:  VIKASPROP_BO
# Working on:  VIKASWSP_BO
# Working on:  VIKRAMTH_BO
# Working on:  VIKSHEN_BO
# Working on:  VIMTALABS_BO
# Working on:  VINATIORGA_BO
# Working on:  VINAYAKPOL_BO
# Working on:  VINCOFE_BO
# Working on:  VINDHYATEL_BO
# Working on:  VINEETLAB_BO
# Working on:  VINTAGES_BO
# Working on:  VINYLINDIA_BO
# Working on:  VINYOFL_BO
# Working on:  VIPCLOTHNG_BO
# Working on:  VIPIND_BO
# Working on:  VIPPYSP_BO
# Working on:  VIPULORG_BO
# Working on:  VIPUL_BO
# Working on:  VIRATCRA_BO
# Working on:  VIRAT_BO
# Working on:  VIRINCHI_BO
# Working on:  VIRTUALG_BO
# Working on:  VIRTUALS_BO
# Working on:  VISAGAR_BO
# Working on:  VISAKAIND_BO
# Working on:  VISASTEEL_BO
# Working on:  VISCO_BO
# Working on:  VISHALBL_BO
# Working on:  VISHAL_BO
# Working on:  VISHNU_BO
# Working on:  VISHWARAJ_BO
# Working on:  VISIONCINE_BO
# Working on:  VISIONCO_BO
# Working on:  VISTAPH_BO
# Working on:  VISTARAMAR_BO
# Working on:  VISVEN_BO
# Working on:  VITESSE_BO
# Working on:  VIVANTA_BO
# Working on:  VIVANZA_BO
# Working on:  VIVIDHA_BO
# Working on:  VIVIDIND_BO
# Working on:  VIVIDM_BO
# Working on:  VIVIMEDLAB_BO
# Working on:  VIVOBIOT_BO
# Working on:  VJLAXMIE_BO
# Working on:  VJTFEDU_BO
# Working on:  VLSFINANCE_BO
# Working on:  VMART_BO
# Working on:  VMS_BO
# Working on:  VMV_BO
# Working on:  VOITHPAPR_BO
# Working on:  VOLLF_BO
# Working on:  VOLTAMP_BO
# Working on:  VOLTAS_BO
# Working on:  VRFILMS_BO
# Working on:  VRLLOG_BO
# Working on:  VRL_BO
# Working on:  VRWODAR_BO
# Working on:  VSFPROJ_BO
# Working on:  VSL_BO
# Working on:  VSSL_BO
# Working on:  VSTIND_BO
# Working on:  VSTTILLERS_BO
# Working on:  VTL_BO
# Working on:  VTMLTD_BO
# Working on:  VXLINSTR_BO
# Working on:  WAAREERTL_BO
# Working on:  WAAREE_BO
# Working on:  WAA_BO
# Working on:  WABAG_BO
# Working on:  WABCOINDIA_BO
# Working on:  WAGEND_BO
# Working on:  WALCHANNAG_BO
# Working on:  WALCHPF_BO
# Working on:  WALLFORT_BO
# Working on:  WANBURY_BO
# Working on:  WARDINMOBI_BO
# Working on:  WARRENTEA_BO
# Working on:  WATERBASE_BO
# Working on:  WEBELSOLAR_BO
# Working on:  WEBSL_BO
# Working on:  WEIZFIN_BO
# Working on:  WEIZMANIND_BO
# Working on:  WELCORP_BO
# Working on:  WELCURE_BO
# Working on:  WELENT_BO
# Working on:  WELINV_BO
# Working on:  WELLESLEY_BO
# Working on:  WELLNESS_BO
# Working on:  WELSPLSOL_BO
# Working on:  WELSPUNIND_BO
# Working on:  WELTI_BO
# Working on:  WENDT_BO
# Working on:  WEPSOLN_BO
# Working on:  WESTLEIRES_BO
# Working on:  WESTLIFE_BO
# Working on:  WHBRADY_BO
# Working on:  WHEELS_BO
# Working on:  WHIRLPOOL_BO
# Working on:  WHITEORG_BO
# Working on:  WILLAMAGOR_BO
# Working on:  WILLIMFI_BO
# Working on:  WIMPLAST_BO
# Working on:  WINDLAS_BO
# Working on:  WINDMACHIN_BO
# Working on:  WINROC_BO
# Working on:  WINSOMBR_BO
# Working on:  WINSOMTX_BO
# Working on:  WIPRO_BO
# Working on:  WIREFABR_BO
# Working on:  WMINIMT_BO
# Working on:  WOCKPHARMA_BO
# Working on:  WOMENNET_BO
# Working on:  WONDERLA_BO
# Working on:  WOODSVILA_BO
# Working on:  WORL_BO
# Working on:  WORTH_BO
# Working on:  WPIL_BO
# Working on:  WSFIN_BO
# Working on:  WSIND_BO
# Working on:  WSTCSTPAPR_BO
# Working on:  WWALUM_BO
# Working on:  XCHANGING_BO
# Working on:  XELPMOC_BO
# Working on:  XPROINDIA_BO
# Working on:  XTGLOBAL_BO
# Working on:  YAARII_BO
# Working on:  YAMNINV_BO
# Working on:  YARNSYN_BO
# Working on:  YASHCHEM_BO
# Working on:  YASHMGM_BO
# Working on:  YASHO_BO
# Working on:  YASHPAKKA_BO
# Working on:  YASHRAJC_BO
# Working on:  YASTF_BO
# Working on:  YESBANK_BO
# Working on:  YOGISUNG_BO
# Working on:  YORKEXP_BO
# Working on:  YSL_BO
# Working on:  YUG_BO
# Working on:  YUKEN_BO
# Working on:  YURANUS_BO
# Working on:  ZBINTXPP_BO
# Working on:  ZDHJERK_BO
# Working on:  ZEAL_BO
# Working on:  ZEELEARN_BO
# Working on:  ZEEL_BO
# Working on:  ZEEMEDIA_BO
# Working on:  ZENIFIB_BO
# Working on:  ZENITHEXPO_BO
# Working on:  ZENITHHE_BO
# Working on:  ZENITHSTL_BO
# Working on:  ZENLABS_BO
# Working on:  ZENOTECH_BO
# Working on:  ZENSARTECH_BO
# Working on:  ZENTEC_BO
# Working on:  ZFSTEERING_BO
# Working on:  ZGAEKWAR_BO
# Working on:  ZGOLDINV_BO
# Working on:  ZHINDHSG_BO
# Working on:  ZHINUDYP_BO
# Working on:  ZIMLAB_BO
# Working on:  ZKHANDEN_BO
# Working on:  ZKHATAUE_BO
# Working on:  ZKOVALIN_BO
# Working on:  ZLEENCON_BO
# Working on:  ZMANSOON_BO
# Working on:  ZMILGFIN_BO
# Working on:  ZMULTIPU_BO
# Working on:  ZNILKENG_BO
# Working on:  ZNIVITRD_BO
# Working on:  ZODIACLOTH_BO
# Working on:  ZODIACVEN_BO
# Working on:  ZODJRDMKJ_BO
# Working on:  ZOMATO_BO
# Working on:  ZPPOLYSA_BO
# Working on:  ZPRBHSTE_BO
# Working on:  ZSANMCOM_BO
# Working on:  ZSARACOM_BO
# Working on:  ZSARVAMA_BO
# Working on:  ZSATYASL_BO
# Working on:  ZSHERAPR_BO
# Working on:  ZSOUTGAS_BO
# Working on:  ZSPEEDCO_BO
# Working on:  ZSVARAJT_BO
# Working on:  ZSVTRADI_BO
# Working on:  ZSWASTSA_BO
# Working on:  ZUARIGLOB_BO
# Working on:  ZUARI_BO
# Working on:  ZWELCAST_BO
# Working on:  ZYDUSWELL_BO
